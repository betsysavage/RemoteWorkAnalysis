# %%
import pandas as pd

# %%
# Read cleaned csv
cleaned_df = pd.read_csv('merged_df_cleaned_040323.csv', index_col= False)
cleaned_df.head()
# Out:
#    responder_id  birth_year  gender  \
# 0             0        1972  Female
# 1             1        1972    Male
# 2             2        1982    Male
# 3             3        1987  Female
# 4             4        1991    Male
#
#                                      industry_desc  \
# 0                                            Other
# 1                                            Other
# 2                                            Other
# 3  Professional, Scientific and Technical Services
# 4                                            Other
#
#                 occupation_desc   organization_size manage_others  \
# 0  Clerical and administrative   Between 20 and 199            No
# 1                      Managers     Between 1 and 4           Yes
# 2                      Managers       More than 200           Yes
# 3                 Professionals  Between 20 and 199            No
# 4                      Managers    Between 5 and 19           Yes
#
# ...

# %%
# create csv for respondents table
respondents_df = cleaned_df[['responder_id', 'birth_year', 'gender',
    'industry_desc', 'occupation_desc', 'manage_others',
    'household', 'years_at_job', 'metro_or_regional']].copy()
respondents_df.head()
# Out:
#    responder_id  birth_year  gender  \
# 0             0        1972  Female
# 1             1        1972    Male
# 2             2        1982    Male
# 3             3        1987  Female
# 4             4        1991    Male
#
#                                      industry_desc  \
# 0                                            Other
# 1                                            Other
# 2                                            Other
# 3  Professional, Scientific and Technical Services
# 4                                            Other
#
#                 occupation_desc manage_others  \
# 0  Clerical and administrative             No
# 1                      Managers           Yes
# 2                      Managers           Yes
# 3                 Professionals            No
# 4                      Managers           Yes
#
#                                     household           years_at_job  \
# 0           Couple with no dependent children      More than 5 years
# ...

# %%
# Save respondents dataframe as csv file
respondents_df.to_csv("respondents.csv", index=False)

# %%
# create csv for orginizational data table
orginizational_data_df = cleaned_df[['responder_id', 'organization_size', 'org_encouraged_rw', 
        'org_prepared_for_rw', 'rw_is_common_at_org', 'rw_permission_is_attainable', 
        'rw_collaboration_easy', 'if_no_covid_employer_encourage_rw',
        'if_no_covid_employer_support_rw', 'if_no_covid_i_would_have_choice_about_rw']].copy()
orginizational_data_df.head()
# Out:
#    responder_id   organization_size           org_encouraged_rw  \
# 0             0  Between 20 and 199              Strongly agree
# 1             1     Between 1 and 4              Somewhat agree
# 2             2       More than 200  Neither agree nor disagree
# 3             3  Between 20 and 199              Strongly agree
# 4             4    Between 5 and 19           Somewhat disagree
#
#   org_prepared_for_rw rw_is_common_at_org rw_permission_is_attainable  \
# 0      Somewhat agree      Somewhat agree              Strongly agree
# 1      Somewhat agree      Somewhat agree              Somewhat agree
# 2      Somewhat agree      Somewhat agree  Neither agree nor disagree
# 3   Somewhat disagree      Somewhat agree              Strongly agree
# 4      Somewhat agree      Strongly agree           Somewhat disagree
#
#   rw_collaboration_easy if_no_covid_employer_encourage_rw  \
# 0        Somewhat agree                 Somewhat disagree
# ...

# %%
# Save orginizational_data dataframe as csv file
orginizational_data_df.to_csv("orginizational_data.csv", index=False)

# %%
# create csv for time management data table
time_management_df = cleaned_df[['responder_id', 'rw_percentage_2020', 
    'preferred_rw_percentage_2020', 'preferred_rw_percentage_future', 
    'productivity_remote_vs_office', 'inperson_hours__commuting', 
    'inperson_hours__working', 'inperson_hours__personal_family_time', 
    'inperson_hours_domestic_responsibilities','remote_hours_commuting',
    'remote_hours_working', 'remote_hours_personal_family_time',
    'remote_hours_domestic_responsibilities', 'commute_time_difference']].copy()
time_management_df.head()
# Out:
#    responder_id rw_percentage_2020 preferred_rw_percentage_2020  \
# 0             0           4-5 days                     4-5 days
# 1             1           1-2 days                     1-2 days
# 2             2           2-3 days                     3-4 days
# 3             3           4-5 days                     4-5 days
# 4             4           4-5 days                     4-5 days
#
#   preferred_rw_percentage_future productivity_remote_vs_office  \
# 0                       4-5 days          much more productive
# 1                       1-2 days               less productive
# 2                       3-4 days               less productive
# 3                       4-5 days             same productivity
# 4                       3-4 days               more productive
#
#    inperson_hours__commuting  inperson_hours__working  \
# 0                        2.0                      8.0
# 1                        2.0                      7.0
# ...

# %%
# Save time management dataframe as csv file
time_management_df.to_csv("time_management.csv", index=False)
