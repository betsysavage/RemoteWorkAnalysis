# %%
# Import dependencies
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Read 2020 survey data
df_2020 = pd.read_csv('2020_rws.csv',encoding='cp1252')
df_2020
# Out:
#       Response ID  What year were you born? What is your gender?  \
# 0               1                      1972               Female
# 1               2                      1972                 Male
# 2               3                      1982                 Male
# 3               4                      1987               Female
# 4               5                      1991                 Male
# ...           ...                       ...                  ...
# 1502         1503                      1995                 Male
# 1503         1504                      1990               Female
# 1504         1505                      1998                 Male
# 1505         1506                      1968               Female
# 1506         1507                      1980                 Male
#
#      Which of the following best describes your industry?  \
# 0                                         Manufacturing
# 1                                       Wholesale Trade
# 2            Electricity, Gas, Water and Waste Services
# 3       Professional, Scientific and Technical Services
# 4                     Transport, Postal and Warehousing
# ...                                                 ...
# 1502            Rental, Hiring and Real Estate Services
# 1503                                    Wholesale Trade
# 1504                  Health Care and Social Assistance
# 1505                  Transport, Postal and Warehousing
# 1506           Information Media and Telecommunications
#
#      Which of the following best describes your industry? (Detailed)  \
# 0                            Food Product Manufacturing
# 1                               Other Goods Wholesaling
# 2                                            Gas Supply
# 3       Professional, Scientific and Technical Services
# 4                                       Other Transport
# ...                                                 ...
# 1502    Rental and Hiring Services (except Real Estate)
# 1503    Grocery, Liquor and Tobacco Product Wholesaling
# 1504                                          Hospitals
# 1505                            Air and Space Transport
# 1506                        Telecommunications Services
#
#      Which of the following best describes your current occupation?  \
# 0                          Clerical and administrative
# 1                                              Managers
# 2                                              Managers
# 3                                         Professionals
# 4                                              Managers
# ...                                                 ...
# 1502                            Technicians and trades
# 1503                                           Managers
# 1504                                      Professionals
# 1505                       Clerical and administrative
# 1506                                           Managers
#
#      Which of the following best describes your current occupation? (Detailed)  \
# 0                    Other Clerical and Administrative
# 1     Chief Executives, General Managers and Legisla...
# 2     Chief Executives, General Managers and Legisla...
# 3                                     ICT Professionals
# 4                                   Specialist Managers
# ...                                                 ...
# 1502           Engineering, ICT and Science Technicians
# 1503  Chief Executives, General Managers and Legisla...
# 1504                               Health Professionals
# 1505                Personal Assistants and Secretaries
# 1506                                Specialist Managers
#
#      How many people are currently employed by your organisation?  \
# 0                                    Between 20 and 199
# 1                                       Between 1 and 4
# 2                                         More than 200
# 3                                    Between 20 and 199
# 4                                      Between 5 and 19
# ...                                                 ...
# 1502                                 Between 20 and 199
# 1503                                 Between 20 and 199
# 1504                                 Between 20 and 199
# 1505                                      More than 200
# 1506                                   Between 5 and 19
#
#      Do you manage people as part of your current occupation?  \
# 0                                                    No
# 1                                                   Yes
# 2                                                   Yes
# 3                                                    No
# 4                                                   Yes
# ...                                                 ...
# 1502                                                NaN
# 1503                                                NaN
# 1504                                                NaN
# 1505                                                NaN
# 1506                                                NaN
#
#      Which of the following best describes your household?  ...  \
# 0                     Couple with no dependent children     ...
# 1                        Couple with dependent children     ...
# 2            One  parent family with dependent children     ...
# 3                        Couple with dependent children     ...
# 4                     Couple with no dependent children     ...
# ...                                                 ...     ...
# 1502                                      Single person     ...
# 1503                     Couple with dependent children     ...
# 1504                                      Single person     ...
# 1505                  Couple with no dependent children     ...
# 1506                     Couple with dependent children     ...
#
#      Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing  \
# 0                      Managing my personal commitments
# 1                      Preparing for work and commuting
# 2                      Managing my personal commitments
# 3                      Preparing for work and commuting
# 4                      Managing my personal commitments
# ...                                                 ...
# 1502                                My mental wellbeing
# 1503                                My mental wellbeing
# 1504                   Managing my personal commitments
# 1505                Managing my family responsibilities
# 1506                Managing my family responsibilities
#
#      Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing  \
# 0                         My opportunities to socialise
# 1                              My working relationships
# 2                      Preparing for work and commuting
# 3                         My opportunities to socialise
# 4                              My working relationships
# ...                                                 ...
# 1502                   Preparing for work and commuting
# 1503                           My working relationships
# 1504                Managing my family responsibilities
# 1505                      My opportunities to socialise
# 1506                           My working relationships
#
#      Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction  \
# 0                      Preparing for work and commuting
# 1                      Preparing for work and commuting
# 2                      Preparing for work and commuting
# 3                             My personal relationships
# 4                      Preparing for work and commuting
# ...                                                 ...
# 1502                Managing my family responsibilities
# 1503                Managing my family responsibilities
# 1504                                My job satisfaction
# 1505                          My personal relationships
# 1506                                My job satisfaction
#
#      Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction  \
# 0                              My working relationships
# 1                              My working relationships
# 2                   Managing my family responsibilities
# 3                              My working relationships
# 4                                     My daily expenses
# ...                                                 ...
# 1502                          My personal relationships
# 1503                          My personal relationships
# 1504                                  My daily expenses
# 1505                Managing my family responsibilities
# 1506                           My working relationships
#
#      Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing  \
# 0                      Managing my personal commitments
# 1                                  My work-life balance
# 2                           The number of hours  I work
# 3                                  My work-life balance
# 4                                  My work-life balance
# ...                                                 ...
# 1502                      My opportunities to socialise
# 1503                        The number of hours  I work
# 1504                        The number of hours  I work
# 1505               My on-the-job learning opportunities
# 1506               My on-the-job learning opportunities
#
#      Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing  \
# 0                           The number of hours  I work
# 1                  My on-the-job learning opportunities
# 2                                   My mental wellbeing
# 3                  My on-the-job learning opportunities
# 4                  My on-the-job learning opportunities
# ...                                                 ...
# 1502                               My work-life balance
# 1503                      My opportunities to socialise
# 1504                      My opportunities to socialise
# 1505                        The number of hours  I work
# 1506                                My mental wellbeing
#
#      Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction  \
# 0                                   My job satisfaction
# 1                                  My work-life balance
# 2                           The number of hours  I work
# 3                                  My work-life balance
# 4                                  My work-life balance
# ...                                                 ...
# 1502                                My job satisfaction
# 1503                          My personal relationships
# 1504                                My job satisfaction
# 1505               My on-the-job learning opportunities
# 1506                          My personal relationships
#
#      Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction  \
# 0                           The number of hours  I work
# 1                  My on-the-job learning opportunities
# 2                                     My daily expenses
# 3                  My on-the-job learning opportunities
# 4                  My on-the-job learning opportunities
# ...                                                 ...
# 1502                          My personal relationships
# 1503                                My job satisfaction
# 1504                               My work-life balance
# 1505                        The number of hours  I work
# 1506                               My work-life balance
#
#      Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction  \
# 0                      Managing my personal commitments
# 1                             My personal relationships
# 2                                   My mental wellbeing
# 3                             My personal relationships
# 4                         My opportunities to socialise
# ...                                                 ...
# 1502                      My opportunities to socialise
# 1503                   Managing my personal commitments
# 1504                      My opportunities to socialise
# 1505                   Managing my personal commitments
# 1506                                My job satisfaction
#
#      Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction
# 0                         My opportunities to socialise
# 1                         My opportunities to socialise
# 2                                     My daily expenses
# 3                                   My job satisfaction
# 4                                   My job satisfaction
# ...                                                 ...
# 1502                                My mental wellbeing
# 1503                          My personal relationships
# 1504                                My mental wellbeing
# 1505                          My personal relationships
# 1506                                My mental wellbeing
#
# [1507 rows x 73 columns]

# %% [markdown]
# # Examining data characteristics

# %%
#Get number of rows and columns
df_2020.shape
# Out:
# (1507, 73)

# %%
#Get column headers
df_2020.columns
# Out:
# Index(['Response ID', 'What year were you born?', 'What is your gender?',
#        'Which of the following best describes your industry?',
#        'Which of the following best describes your industry? (Detailed)',
#        'Which of the following best describes your current occupation?',
#        'Which of the following best describes your current occupation? (Detailed)',
#        'How many people are currently employed by your organisation?',
#        'Do you manage people as part of your current occupation?',
#        'Which of the following best describes your household?',
#        'How long have you been in your current job?', 'Metro / Regional',
#        'Thinking about your current job, how much of your time did you spend remote working last year?',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation was well prepared for me to work remotely',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - It was common for people in my organisation to work remotely',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - It was easy to get permission to work remotely',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - I could easily collaborate with colleagues when working remotely',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - I would recommend remote working to others',
#        'How much of your time would you have preferred to work remotely last year?',
#        'Thinking about your current job, how much of your time did you spend remote working in the last 3 months?',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - My organisation was well prepared for me to work remotely',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - It was common for people in my organisation to work remotely',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - It was easy to get permission to work remotely',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - I could easily collaborate with colleagues when working remotely',
#        'Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - I would recommend remote working to others',
#        'How much of your time would you have preferred to work remotely in the last 3 months?',
#        'Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?',
#        'Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - My employer would encourage more remote working',
#        'Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - My employer would make changes to support remote working',
#        'Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - I would have more choice about whether I work remotely',
#        'This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.  \nPlease compare your productivity when you work remotely to when you work at your employer’s workplace.  \nRoughly how productive are you, each hour, when you work remotely?',
#        'On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting',
#        'On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working',
#        'On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time',
#        'On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Caring and domestic responsibilities',
#        'On a day when you do remote work, how many hours would you spend doing the following activities? - Preparing for work and commuting',
#        'On a day when you do remote work, how many hours would you spend doing the following activities? - Working',
#        'On a day when you do remote work, how many hours would you spend doing the following activities? - Personal and family time',
#        'On a day when you do remote work, how many hours would you spend doing the following activities? - Caring and domestic responsibilities',
#        'From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities',
#        'From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities',
#        'From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Cyber security ; Lack of motivation ; Lack of motivation',
#        'From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Cyber security ; Lack of motivation ; Lack of motivation',
#        'From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Cyber security ; Lack of motivation ; Lack of motivation',
#        'From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Cyber security ; Lack of motivation ; Lack of motivation',
#        'From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the most significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the least significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely',
#        'From the following, please select the most significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the least significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the most significant barrier to doing your work remotely - My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'From the following, please select the least significant barrier to doing your work remotely - My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction',
#        'Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction',
#        'Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction'],
#       dtype='object')

# %%
#Check data types
df_2020.dtypes
# Out:
# Response ID                                                                                                                                                                                                                                                                                                int64
# What year were you born?                                                                                                                                                                                                                                                                                   int64
# What is your gender?                                                                                                                                                                                                                                                                                      object
# Which of the following best describes your industry?                                                                                                                                                                                                                                                      object
# Which of the following best describes your industry? (Detailed)                                                                                                                                                                                                                                           object
#                                                                                                                                                                                                                                                                                                            ...
# Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing    object
# Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction                        object
# Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction                       object
# Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction                           object
# Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction                          object
# Length: 73, dtype: object

# %%
#Sum of each data type
df_2020.dtypes.value_counts()
# Out:
# object     63
# float64     8
# int64       2
# dtype: int64

# %%
#Generate descriptive statistics of numerical columns
df_2020.describe()
# Out:
#        Response ID  What year were you born?  \
# count  1507.000000               1507.000000
# mean    754.000000               1974.791639
# std     435.177741                 11.875588
# min       1.000000               1900.000000
# 25%     377.500000               1965.000000
# 50%     754.000000               1975.000000
# 75%    1130.500000               1985.000000
# max    1507.000000               2001.000000
#
#        On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting  \
# count                                        1507.000000
# mean                                            1.795786
# std                                             1.379599
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.500000
# 75%                                             2.000000
# max                                            20.000000
#
#        On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working  \
# count                                        1507.000000
# mean                                            7.531128
# std                                             2.626245
# min                                             0.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                             8.000000
# max                                            60.000000
#
#        On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time  \
# count                                        1507.000000
# mean                                            3.969642
# std                                             3.114015
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             5.000000
# max                                            20.000000
#
#        On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Caring and domestic responsibilities  \
# count                                        1507.000000
# mean                                            2.296981
# std                                             2.056728
# min                                            -1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                            20.000000
#
#        On a day when you do remote work, how many hours would you spend doing the following activities? - Preparing for work and commuting  \
# count                                        1507.000000
# mean                                            0.668653
# std                                             1.345080
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.300000
# 75%                                             1.000000
# max                                            20.000000
#
#        On a day when you do remote work, how many hours would you spend doing the following activities? - Working  \
# count                                        1507.000000
# mean                                            7.832887
# std                                             2.560533
# min                                             0.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                             9.000000
# max                                            40.000000
#
#        On a day when you do remote work, how many hours would you spend doing the following activities? - Personal and family time  \
# count                                        1507.000000
# mean                                            4.660186
# std                                             3.182748
# min                                             0.000000
# 25%                                             2.500000
# 50%                                             4.000000
# 75%                                             6.000000
# max                                            20.000000
#
#        On a day when you do remote work, how many hours would you spend doing the following activities? - Caring and domestic responsibilities
# count                                        1507.000000
# mean                                            2.628832
# std                                             2.131725
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                            20.000000

# %%
# Check for duplicates
df_2020.duplicated().sum()
# Out:
# 0

# %%
# Check for null values in each column
for column in df_2020.columns:
    print(f"Column {column} has {df_2020[column].isnull().sum()} null values")
# Out:
# Column Response ID has 0 null values
# Column What year were you born? has 0 null values
# Column What is your gender? has 0 null values
# Column Which of the following best describes your industry? has 0 null values
# Column Which of the following best describes your industry? (Detailed) has 0 null values
# Column Which of the following best describes your current occupation? has 0 null values
# Column Which of the following best describes your current occupation? (Detailed) has 0 null values
# Column How many people are currently employed by your organisation? has 0 null values
# Column Do you manage people as part of your current occupation? has 136 null values
# Column Which of the following best describes your household? has 0 null values
# Column How long have you been in your current job? has 0 null values
# Column Metro / Regional has 0 null values
# Column Thinking about your current job, how much of your time did you spend remote working last year? has 0 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely has 250 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation was well prepared for me to work remotely has 250 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - It was common for people in my organisation to work remotely has 250 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - It was easy to get permission to work remotely has 250 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - I could easily collaborate with colleagues when working remotely has 250 null values
# Column Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - I would recommend remote working to others has 250 null values
# Column How much of your time would you have preferred to work remotely last year? has 0 null values
# Column Thinking about your current job, how much of your time did you spend remote working in the last 3 months? has 0 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely has 31 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - My organisation was well prepared for me to work remotely has 31 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - It was common for people in my organisation to work remotely has 31 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - It was easy to get permission to work remotely has 31 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - I could easily collaborate with colleagues when working remotely has 31 null values
# Column Thinking about remote working in the last 3 months, how strongly do you agree or disagree with the following statements? - I would recommend remote working to others has 31 null values
# Column How much of your time would you have preferred to work remotely in the last 3 months? has 0 null values
# Column Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely? has 136 null values
# Column Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - My employer would encourage more remote working has 0 null values
# Column Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - My employer would make changes to support remote working has 0 null values
# Column Imagine that COVID-19 is cured or eradicated.  How likely would you consider the following statements? - I would have more choice about whether I work remotely has 0 null values
# Column This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.
# Please compare your productivity when you work remotely to when you work at your employer’s workplace.
# Roughly how productive are you, each hour, when you work remotely? has 0 null values
# Column On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Preparing for work and commuting has 0 null values
# Column On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working has 0 null values
# Column On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Personal and family time has 0 null values
# Column On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Caring and domestic responsibilities has 0 null values
# Column On a day when you do remote work, how many hours would you spend doing the following activities? - Preparing for work and commuting has 0 null values
# Column On a day when you do remote work, how many hours would you spend doing the following activities? - Working has 0 null values
# Column On a day when you do remote work, how many hours would you spend doing the following activities? - Personal and family time has 0 null values
# Column On a day when you do remote work, how many hours would you spend doing the following activities? - Caring and domestic responsibilities has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Cyber security ; Lack of motivation ; Lack of motivation has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Cyber security ; Lack of motivation ; Lack of motivation has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Connectivity (internet connection) ; Feeling left out and/or isolated ; Poor management ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Cyber security ; Lack of motivation ; Lack of motivation has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Cyber security ; Lack of motivation ; Lack of motivation has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - IT equipment (computer, printer, etc.) ; Difficulty collaborating remotely ; Caring responsibilities ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - Cyber security ; Lack of motivation ; Lack of motivation ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the most significant barrier to doing your work remotely - My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column From the following, please select the least significant barrier to doing your work remotely - My organisation's software and systems ; My workspace (e.g. suitable chair, lighting, noise levels, facilities) ; I have tasks that can't be done remotely ; Lack of remote working skills ; My living situation (e.g. location, home size, who I live with) ; Management discourages remote working has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my family responsibilities ; My working relationships ; Preparing for work and commuting ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - The number of hours  I work ; My work-life balance ; My on-the-job learning opportunities ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the best aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values
# Column Compare remote working to working at your employer’s workplace. Select the worst aspect of remote working for you - Managing my personal commitments ; My opportunities to socialise ; My mental wellbeing ; My daily expenses ; My personal relationships ; My job satisfaction has 0 null values

# %% [markdown]
# # Examining demographics

# %%
# Examining age
df_2020['What year were you born?'].describe()
# Out:
# count    1507.000000
# mean     1974.791639
# std        11.875588
# min      1900.000000
# 25%      1965.000000
# 50%      1975.000000
# 75%      1985.000000
# max      2001.000000
# Name: What year were you born?, dtype: float64

# %%
# Examining gender
df_2020['What is your gender?'].value_counts()
# Out:
# Male              847
# Female            658
# Rather not say      2
# Name: What is your gender?, dtype: int64

# %%
# Examining most common industry types
df_2020['Which of the following best describes your industry?'].value_counts()
# Out:
# Professional, Scientific and Technical Services    259
# Financial and Insurance Services                   173
# Education and Training                             144
# Information Media and Telecommunications           114
# Health Care and Social Assistance                  103
# Other Services                                      90
# Retail Trade                                        87
# Manufacturing                                       82
# Public Administration and Safety                    81
# Administrative and Support Services                 76
# Transport, Postal and Warehousing                   57
# Construction                                        56
# Wholesale Trade                                     44
# Arts and Recreation Services                        38
# Accommodation and Food Services                     32
# Electricity, Gas, Water and Waste Services          29
# Rental, Hiring and Real Estate Services             25
# Agriculture, Forestry and Fishing                    9
# Mining                                               8
# Name: Which of the following best describes your industry?, dtype: int64

# %%
df_2020['How many people are currently employed by your organisation?'].value_counts()
# Out:
# More than 200             739
# Between 20 and 199        380
# Between 5 and 19          234
# Between 1 and 4            91
# I am the only employee     63
# Name: How many people are currently employed by your organisation?, dtype: int64

# %%
df_2020['How long have you been in your current job?'].value_counts()
# Out:
# More than 5 years          801
# Between 1 and 5 years      543
# Between 6 and 12 months    163
# Name: How long have you been in your current job?, dtype: int64

# %%
df_2020['Metro / Regional'].value_counts()
# Out:
# Metro       1223
# Regional     284
# Name: Metro / Regional, dtype: int64

# %%
df_2020['Do you manage people as part of your current occupation?'].value_counts()
# Out:
# Yes    693
# No     678
# Name: Do you manage people as part of your current occupation?, dtype: int64

# %%
df_2020['Thinking about your current job, how much of your time did you spend remote working last year?'].value_counts()
# Out:
# Less than 10% of my time                              268
# Rarely or never                                       250
# 20%                                                   208
# 50% - I spent about half of my time remote working    156
# 10%                                                   147
# 30%                                                   122
# 100% - I spent all of my time remote working           98
# 40%                                                    83
# 60%                                                    56
# 80%                                                    43
# 70%                                                    43
# 90%                                                    33
# Name: Thinking about your current job, how much of your time did you spend remote working last year?, dtype: int64

# %%
# Examining time spent remote working
df_2020['Thinking about your current job, how much of your time did you spend remote working in the last 3 months?'].value_counts()
# Out:
# 100% - I spent all of my time remote working          543
# 90%                                                   146
# 50% - I spent about half of my time remote working    137
# 80%                                                   109
# 20%                                                   108
# Less than 10% of my time                               84
# 40%                                                    77
# 30%                                                    76
# 70%                                                    70
# 60%                                                    67
# 10%                                                    59
# Rarely or never                                        31
# Name: Thinking about your current job, how much of your time did you spend remote working in the last 3 months?, dtype: int64

# %%
# Plotting distribution of time spent remote working
df_2020['Thinking about your current job, how much of your time did you spend remote working in the last 3 months?'].value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Examining preferences for time spent remote working in the future
df_2020['Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?'].value_counts()
# Out:
# 50% - About half of my time             304
# 100% - All of my time                   166
# 20%                                     128
# 80%                                     124
# 60%                                     105
# 40%                                     105
# 30%                                      90
# I would prefer not to work remotely      89
# 70%                                      80
# 90%                                      69
# Less than 10% of my time                 58
# 10%                                      53
# Name: Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?, dtype: int64

# %%
# Plotting distribution of preferences for time spent remote working in the future
df_2020['Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?'].value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Plotting preferences for remote work by gender
df_2020.groupby(['Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?','What is your gender?']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?'>

# %%
#Plotting preferences for remote work by management responsibilities
df_2020.groupby(['Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?','Do you manage people as part of your current occupation?']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?'>

# %%
#Plotting productivity comparison - remote vs in-person
df_2020['This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.  \nPlease compare your productivity when you work remotely to when you work at your employer’s workplace.  \nRoughly how productive are you, each hour, when you work remotely?'].value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>
