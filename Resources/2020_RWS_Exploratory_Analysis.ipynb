# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('2020_rws.csv',encoding='cp1252')

# %%
df.head()
# Out:
#    Response ID  What year were you born? What is your gender?  \
# 0            1                      1972               Female
# 1            2                      1972                 Male
# 2            3                      1982                 Male
# 3            4                      1987               Female
# 4            5                      1991                 Male
#
#   Which of the following best describes your industry?  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2         Electricity, Gas, Water and Waste Services
# 3    Professional, Scientific and Technical Services
# 4                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# ...

# %%
## View columns
df.columns
# Out:
# Index(['Response ID', 'What year were you born?', 'What is your gender?',
#        'Which of the following best describes your industry?',
#        'Which of the following best describes your industry? (Detailed)',
#        'Which of the following best describes your current occupation?',
#        'Which of the following best describes your current occupation? (Detailed)',
#        'How many people are currently employed by your organisation?',
#        'Do you manage people as part of your current occupation?',
#        'Which of the following best describes your household?',
#        'How long have you been in your current job?', 'Metro / Regional',
#        'Thinking about your current job, how much of your time did you spend remote working last year?',
#        'Thinking about remote working last year, how strongly do you agree or disagree with the following statements? - My organisation encouraged people to work remotely',
# ...

# %%
## Value counts of proportion of remote work
df['Thinking about your current job, how much of your time did you spend remote working last year?'].value_counts()
# Out:
# Less than 10% of my time                              268
# Rarely or never                                       250
# 20%                                                   208
# 50% - I spent about half of my time remote working    156
# 10%                                                   147
# 30%                                                   122
# 100% - I spent all of my time remote working           98
# 40%                                                    83
# 60%                                                    56
# 80%                                                    43
# 70%                                                    43
# 90%                                                    33
# Name: Thinking about your current job, how much of your time did you spend remote working last year?, dtype: int64

# %%
## Vlue counts of preference for remote work
df['How much of your time would you have preferred to work remotely last year?'].value_counts()
# Out:
# 50% - About half of my time                     300
# 20%                                             219
# 100% - All of my time                           157
# Less than 10% of my time                        126
# 30%                                             123
# 40%                                             121
# I would not have preferred to work remotely     108
# 10%                                              97
# 80%                                              80
# 60%                                              66
# 70%                                              57
# 90%                                              53
# Name: How much of your time would you have preferred to work remotely last year?, dtype: int64

# %%
df['How much of your time would you have preferred to work remotely in the last 3 months?'].value_counts()
# Out:
# 100% - All of my time                           472
# 50% - About half of my time                     225
# 80%                                             140
# 20%                                             104
# 90%                                             103
# 40%                                              86
# 70%                                              81
# 60%                                              72
# I would not have preferred to work remotely      62
# Less than 10% of my time                         56
# 30%                                              54
# 10%                                              52
# Name: How much of your time would you have preferred to work remotely in the last 3 months?, dtype: int64

# %%
df['Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?'].value_counts()
# Out:
# 50% - About half of my time             304
# 100% - All of my time                   166
# 20%                                     128
# 80%                                     124
# 60%                                     105
# 40%                                     105
# 30%                                      90
# I would prefer not to work remotely      89
# 70%                                      80
# 90%                                      69
# Less than 10% of my time                 58
# 10%                                      53
# Name: Imagine that COVID-19 is cured or eradicated. Going forward, how much of your time would you prefer to work remotely?, dtype: int64

# %%
df['This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.  \nPlease compare your productivity when you work remotely to when you work at your employer’s workplace.  \nRoughly how productive are you, each hour, when you work remotely?'].value_counts()
# Out:
# My productivity is about same when I work remotely         437
# I’m 50% more productive when working remotely (or more)    220
# I’m 20% more productive when working remotely              208
# I’m 30% more productive when working remotely              193
# I’m 10% more productive when working remotely              101
# I’m 10% less productive when working remotely               97
# I’m 20% less productive when working remotely               90
# I’m 40% more productive when working remotely               84
# I’m 30% less productive when working remotely               43
# I’m 50% less productive when working remotely (or less)     27
# I’m 40% less productive when working remotely                7
# ...

# %%
df['On a day when you do remote work, how many hours would you spend doing the following activities? - Working'].value_counts()
# Out:
# 8.00     441
# 9.00     201
# 7.00     172
# 10.00    154
# 6.00     110
# 5.00      74
# 7.50      58
# 4.00      43
# 12.00     42
# 11.00     34
# 8.50      31
# 2.00      25
# 3.00      24
# 1.00      20
# 9.50      19
# 6.50       7
# 13.00      7
# 14.00      5
# 0.00       3
# 0.50       3
# 20.00      3
# 16.00      3
# 10.50      3
# 7.60       3
# 6.25       2
# 4.50       2
# 12.50      2
# 2.50       2
# 15.00      2
# 7.35       1
# 7.90       1
# 5.50       1
# 7.75       1
# 3.50       1
# 6.90       1
# 18.00      1
# 7.66       1
# 23.00      1
# 9.80       1
# 33.00      1
# 40.00      1
# Name: On a day when you do remote work, how many hours would you spend doing the following activities? - Working, dtype: int64

# %%
## Need to sort out the impact of the comma!!
df['On a day when you attend your employer's workplace, how many hours would you spend doing the following activities? - Working']
