# %% [markdown]
# # Worker Productivity Resampling

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %% [markdown]
# # Read the CSV and Perform Preliminary Cleaning/Setup

# %%
columns = [
"birth_year",
"gender",
"industry_desc",
"occupation_desc",
"organization_size",
"manage_others",
"household",
"years_at_job",
"metro_or_regional",
"rw_percentage_2020",
"org_encouraged_rw",
"org_prepared_for_rw",
"rw_is_common_at_org",
"rw_permission_is_attainable",
"rw_collaboration_easy",
"preferred_rw_percentage_2020",
"preferred_rw_percentage_future",
"if_no_covid_employer_encourage_rw",
"if_no_covid_employer_support_rw",
"if_no_covid_i_would_have_choice_about_rw",
"productivity_remote_vs_office",
"inperson_hours__commuting",
"inperson_hours__working",
"inperson_hours__personal_family_time",
"inperson_hours_domestic_responsibilities",
"remote_hours_commuting",
"remote_hours_working",
"remote_hours_personal_family_time",
"remote_hours_domestic_responsibilities",
]

target = ["productivity_remote_vs_office"]

# %%
# Load the data
file_path = Path('merged_df_cleaned_040323.csv')
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()

# Convert the target column values to More_or_same_productive and less_productive based on their values
x = dict.fromkeys(['more productive','much more productive','same productivity'], 'more_or_same_productive')
df = df.replace(x)

x = dict.fromkeys(['less productive', 'much less productive'], 'less_productive')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    birth_year  gender                                    industry_desc  \
# 0        1972  Female                                            Other
# 1        1972    Male                                            Other
# 2        1982    Male                                            Other
# 3        1987  Female  Professional, Scientific and Technical Services
# 4        1991    Male                                            Other
#
#                 occupation_desc   organization_size manage_others  \
# 0  Clerical and administrative   Between 20 and 199            No
# 1                      Managers     Between 1 and 4           Yes
# 2                      Managers       More than 200           Yes
# 3                 Professionals  Between 20 and 199            No
# 4                      Managers    Between 5 and 19           Yes
#
#                                     household           years_at_job  \
# 0           Couple with no dependent children      More than 5 years
# 1              Couple with dependent children      More than 5 years
# 2  One  parent family with dependent children      More than 5 years
# 3              Couple with dependent children  Between 1 and 5 years
# 4           Couple with no dependent children      More than 5 years
#
#   metro_or_regional rw_percentage_2020  ...  \
# 0          Regional           4-5 days  ...
# 1             Metro           1-2 days  ...
# 2             Metro           2-3 days  ...
# 3             Metro           4-5 days  ...
# 4             Metro           4-5 days  ...
#
#   if_no_covid_i_would_have_choice_about_rw productivity_remote_vs_office  \
# 0                        Strongly disagree       more_or_same_productive
# 1                           Somewhat agree               less_productive
# 2                           Somewhat agree               less_productive
# 3                           Somewhat agree       more_or_same_productive
# 4                        Strongly disagree       more_or_same_productive
#
#   inperson_hours__commuting inperson_hours__working  \
# 0                       2.0                     8.0
# 1                       2.0                     7.0
# 2                       6.0                     1.0
# 3                       1.0                     9.0
# 4                       1.0                     8.0
#
#   inperson_hours__personal_family_time  \
# 0                                  2.0
# 1                                  3.0
# 2                                  6.0
# 3                                  1.0
# 4                                  3.5
#
#   inperson_hours_domestic_responsibilities remote_hours_commuting  \
# 0                                      2.0                    0.5
# 1                                      3.0                    0.0
# 2                                      5.0                    5.0
# 3                                      2.0                    0.0
# 4                                      2.0                    0.0
#
#   remote_hours_working remote_hours_personal_family_time  \
# 0                  8.0                               3.5
# 1                  7.0                               3.0
# 2                  2.0                               7.0
# 3                  9.0                               3.0
# 4                  6.0                               4.0
#
#   remote_hours_domestic_responsibilities
# 0                                    2.0
# 1                                    3.0
# 2                                    7.0
# 3                                    2.0
# 4                                    3.0
#
# [5 rows x 29 columns]

# %%
#show string datatypes for encoding
df.select_dtypes(include=['object'])
# Out:
#       gender                                    industry_desc  \
# 0     Female                                            Other
# 1       Male                                            Other
# 2       Male                                            Other
# 3     Female  Professional, Scientific and Technical Services
# 4       Male                                            Other
# ...      ...                                              ...
# 3014    Male                                            Other
# 3015  Female                Health Care and Social Assistance
# 3016  Female                                            Other
# 3017  Female                           Education and Training
# 3018  Female                                            Other
#
#                                         occupation_desc   organization_size  \
# 0                          Clerical and administrative   Between 20 and 199
# 1                                              Managers     Between 1 and 4
# 2                                              Managers       More than 200
# 3                                         Professionals  Between 20 and 199
# 4                                              Managers    Between 5 and 19
# ...                                                 ...                 ...
# 3014  Managers - Chief Executives, General Managers ...    Between 5 and 19
# 3015                                              Other    Between 5 and 19
# 3016                                              Other  Between 20 and 199
# 3017  Managers - Chief Executives, General Managers ...     Between 1 and 4
# 3018                                              Other       More than 200
#
#      manage_others                                   household  \
# 0               No           Couple with no dependent children
# 1              Yes              Couple with dependent children
# 2              Yes  One  parent family with dependent children
# 3               No              Couple with dependent children
# 4              Yes           Couple with no dependent children
# ...            ...                                         ...
# 3014           Yes              Couple with dependent children
# 3015           Yes                   Multiple family household
# 3016            No   One parent family with dependent children
# 3017           Yes           Couple with no dependent children
# 3018            No              Couple with dependent children
#
#                years_at_job metro_or_regional rw_percentage_2020  \
# 0         More than 5 years          Regional           4-5 days
# 1         More than 5 years             Metro           1-2 days
# 2         More than 5 years             Metro           2-3 days
# 3     Between 1 and 5 years             Metro           4-5 days
# 4         More than 5 years             Metro           4-5 days
# ...                     ...               ...                ...
# 3014  Between 1 and 5 years             Metro           1-2 days
# 3015      More than 5 years             Metro           0-1 days
# 3016      More than 5 years          Regional           0-1 days
# 3017      More than 5 years             Metro           0-1 days
# 3018  Between 1 and 5 years          Regional           1-2 days
#
#                org_encouraged_rw         org_prepared_for_rw  \
# 0                 Strongly agree              Somewhat agree
# 1                 Somewhat agree              Somewhat agree
# 2     Neither agree nor disagree              Somewhat agree
# 3                 Strongly agree           Somewhat disagree
# 4              Somewhat disagree              Somewhat agree
# ...                          ...                         ...
# 3014  Neither agree nor disagree              Somewhat agree
# 3015           Somewhat disagree           Somewhat disagree
# 3016           Strongly disagree           Strongly disagree
# 3017              Somewhat agree              Somewhat agree
# 3018  Neither agree nor disagree  Neither agree nor disagree
#
#              rw_is_common_at_org rw_permission_is_attainable  \
# 0                 Somewhat agree              Strongly agree
# 1                 Somewhat agree              Somewhat agree
# 2                 Somewhat agree  Neither agree nor disagree
# 3                 Somewhat agree              Strongly agree
# 4                 Strongly agree           Somewhat disagree
# ...                          ...                         ...
# 3014  Neither agree nor disagree              Somewhat agree
# 3015           Strongly disagree  Neither agree nor disagree
# 3016           Strongly disagree           Strongly disagree
# 3017              Somewhat agree              Strongly agree
# 3018              Somewhat agree  Neither agree nor disagree
#
#            rw_collaboration_easy preferred_rw_percentage_2020  \
# 0                 Somewhat agree                     4-5 days
# 1                 Somewhat agree                     1-2 days
# 2                 Somewhat agree                     3-4 days
# 3                 Strongly agree                     4-5 days
# 4                 Somewhat agree                     4-5 days
# ...                          ...                          ...
# 3014              Somewhat agree                     2-3 days
# 3015  Neither agree nor disagree                     0-1 days
# 3016              Strongly agree                     4-5 days
# 3017              Somewhat agree                     0-1 days
# 3018  Neither agree nor disagree                     1-2 days
#
#      preferred_rw_percentage_future if_no_covid_employer_encourage_rw  \
# 0                          4-5 days                 Somewhat disagree
# 1                          1-2 days                    Somewhat agree
# 2                          3-4 days                    Somewhat agree
# 3                          4-5 days                    Somewhat agree
# 4                          3-4 days                 Strongly disagree
# ...                             ...                               ...
# 3014                       1-2 days                   Somewhat likely
# 3015                       0-1 days                     Very unlikely
# 3016                       4-5 days                     Very unlikely
# 3017                       0-1 days                   Somewhat likely
# 3018                       1-2 days                   Somewhat likely
#
#      if_no_covid_employer_support_rw if_no_covid_i_would_have_choice_about_rw  \
# 0                  Somewhat disagree                        Strongly disagree
# 1                     Somewhat agree                           Somewhat agree
# 2                     Somewhat agree                           Somewhat agree
# 3                     Strongly agree                           Somewhat agree
# 4                  Strongly disagree                        Strongly disagree
# ...                              ...                                      ...
# 3014      Neither unlikely or likely                          Somewhat likely
# 3015                   Very unlikely                            Very unlikely
# 3016                   Very unlikely                            Very unlikely
# 3017                 Somewhat likely                          Somewhat likely
# 3018                 Somewhat likely                          Somewhat likely
#
#      productivity_remote_vs_office
# 0          more_or_same_productive
# 1                  less_productive
# 2                  less_productive
# 3          more_or_same_productive
# 4          more_or_same_productive
# ...                            ...
# 3014       more_or_same_productive
# 3015       more_or_same_productive
# 3016       more_or_same_productive
# 3017       more_or_same_productive
# 3018       more_or_same_productive
#
# [3019 rows x 20 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns= 'productivity_remote_vs_office')
X = pd.get_dummies(X)

# Create our target
y = df[target]

# %%
X.describe()
# Out:
#         birth_year  inperson_hours__commuting  inperson_hours__working  \
# count  3019.000000                3019.000000              3019.000000
# mean   1977.012587                   1.920543                 7.622295
# std      12.059818                   1.193116                 1.813712
# min    1900.000000                   0.000000                 1.000000
# 25%    1967.000000                   1.000000                 7.000000
# 50%    1978.000000                   2.000000                 8.000000
# 75%    1987.000000                   2.500000                 8.000000
# max    2002.000000                   6.000000                14.000000
#
#        inperson_hours__personal_family_time  \
# count                           3019.000000
# mean                               3.682458
# std                                2.053795
# min                                0.000000
# 25%                                2.000000
# 50%                                3.500000
# 75%                                5.000000
# max                               11.000000
#
#        inperson_hours_domestic_responsibilities  remote_hours_commuting  \
# count                               3019.000000             3019.000000
# mean                                   2.429530                0.731305
# std                                    1.586734                1.078736
# min                                   -1.000000                0.000000
# 25%                                    1.000000                0.000000
# 50%                                    2.000000                0.500000
# 75%                                    3.000000                1.000000
# max                                    8.000000                5.000000
#
#        remote_hours_working  remote_hours_personal_family_time  \
# count           3019.000000                        3019.000000
# mean               7.914660                           4.294395
# std                2.028679                           2.186404
# min                1.000000                           0.000000
# 25%                7.000000                           3.000000
# 50%                8.000000                           4.000000
# 75%                9.000000                           5.000000
# max               15.000000                          12.000000
#
#        remote_hours_domestic_responsibilities  gender_Female  ...  \
# count                             3019.000000    3019.000000  ...
# mean                                 2.719361       0.477973  ...
# std                                  1.640603       0.499597  ...
# min                                  0.000000       0.000000  ...
# 25%                                  2.000000       0.000000  ...
# 50%                                  2.500000       0.000000  ...
# 75%                                  4.000000       1.000000  ...
# max                                  8.000000       1.000000  ...
#
#        if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree  \
# count                                        3019.000000
# mean                                            0.103345
# std                                             0.304460
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely  \
# count                                        3019.000000
# mean                                            0.127194
# std                                             0.333246
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat agree  \
# count                                        3019.000000
# mean                                            0.181186
# std                                             0.385236
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat disagree  \
# count                                        3019.000000
# mean                                            0.054654
# std                                             0.227341
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat likely  \
# count                                        3019.000000
# mean                                            0.150712
# std                                             0.357827
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely  \
# count                                        3019.000000
# mean                                            0.073534
# std                                             0.261055
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly agree  \
# count                                        3019.000000
# mean                                            0.121563
# std                                             0.326835
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly disagree  \
# count                                        3019.000000
# mean                                            0.038423
# std                                             0.192248
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very likely  \
# count                                        3019.000000
# mean                                            0.084134
# std                                             0.277634
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very unlikely
# count                                        3019.000000
# mean                                            0.065253
# std                                             0.247013
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
# [8 rows x 133 columns]

# %%
# Check the balance of our target values
y['productivity_remote_vs_office'].value_counts()
# Out:
# more_or_same_productive    2539
# less_productive             480
# Name: productivity_remote_vs_office, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Oversampling
#
# In this section,we compared two oversampling algorithms to determine which algorithm results in the best performance. We oversampled the data using the naive random oversampling algorithm and the SMOTE algorithm.
#
# We used a random state of 1 for each sampling algorithm to ensure consistency between tests

# %% [markdown]
# ### Naive Random Oversampling

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.6455162741612975

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[ 69,  43],
#        [209, 434]])

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.25      0.62      0.67      0.35      0.64      0.41       112
# more_or_same_productive       0.91      0.67      0.62      0.77      0.64      0.42       643
#
#             avg / total       0.81      0.67      0.62      0.71      0.64      0.42       755

# %% [markdown]
# ### SMOTE Oversampling

# %%
# Resample the training data with SMOTE
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1,
sampling_strategy='auto').fit_resample(
   X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5583828593645856

# %%
# Display the confusion matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[ 19,  93],
#        [ 34, 609]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.36      0.17      0.95      0.23      0.40      0.15       112
# more_or_same_productive       0.87      0.95      0.17      0.91      0.40      0.17       643
#
#             avg / total       0.79      0.83      0.28      0.81      0.40      0.17       755

# %% [markdown]
# # Undersampling
#
# In this section, we tested an undersampling algorithm to determine which algorithm results in the best performance compared to the oversampling algorithms above. We undersampled the data using the Cluster Centroids algorithm.
#
# We used a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the data using the ClusterCentroids resampler
from imblearn.under_sampling import ClusterCentroids
cc = ClusterCentroids(random_state=1)
X_resampled, y_resampled = cc.fit_resample(X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5583828593645856

# %%
# Display the confusion matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[106,   6],
#        [596,  47]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.15      0.95      0.07      0.26      0.26      0.08       112
# more_or_same_productive       0.89      0.07      0.95      0.14      0.26      0.06       643
#
#             avg / total       0.78      0.20      0.82      0.15      0.26      0.06       755

# %% [markdown]
# # Combination (Over and Under) Sampling
#
# In this section, we used a combination over- and under-sampling algorithm to determine if the algorithm results in the best performance compared to the other sampling algorithms above. We resampled the data using the SMOTEENN algorithm.
#
# We used a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the training data with SMOTEENN
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5097617196178627

# %%
# Display the confusion matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 74,  38],
#        [195, 448]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.28      0.66      0.70      0.39      0.68      0.46       112
# more_or_same_productive       0.92      0.70      0.66      0.79      0.68      0.46       643
#
#             avg / total       0.83      0.69      0.67      0.73      0.68      0.46       755
