# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Preliminary Cleaning/Setup

# %%
columns = [
"birth_year",
"gender",
"industry_desc",
"occupation_desc",
"organization_size",
"manage_others",
"household",
"years_at_job",
"metro_or_regional",
"rw_percentage_2020",
"org_encouraged_rw",
"org_prepared_for_rw",
"rw_is_common_at_org",
"rw_permission_is_attainable",
"rw_collaboration_easy",
"preferred_rw_percentage_2020",
"preferred_rw_percentage_future",
"if_no_covid_employer_encourage_rw",
"if_no_covid_employer_support_rw",
"if_no_covid_i_would_have_choice_about_rw",
"productivity_remote_vs_office",
"inperson_hours__commuting",
"inperson_hours__working",
"inperson_hours__personal_family_time",
"inperson_hours_domestic_responsibilities",
"remote_hours_commuting",
"remote_hours_working",
"remote_hours_personal_family_time",
"remote_hours_domestic_responsibilities",
]

target = ["preferred_rw_percentage_future"]

# %%
# Load the data
file_path = Path('merged_df_cleaned_040323.csv')
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()

# Convert the target column values to More_or_same_productive and less_productive based on their values
x = dict.fromkeys(['0-1 days','1-2 days','2-3 days','No response'], '0-3 days remote')
df = df.replace(x)

x = dict.fromkeys(['3-4 days', '4-5 days'], '3-5 days remote')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    birth_year  gender                                    industry_desc  \
# 0        1972  Female                                            Other
# 1        1972    Male                                            Other
# 2        1982    Male                                            Other
# 3        1987  Female  Professional, Scientific and Technical Services
# 4        1991    Male                                            Other
#
#                 occupation_desc   organization_size manage_others  \
# 0  Clerical and administrative   Between 20 and 199            No
# 1                      Managers     Between 1 and 4           Yes
# 2                      Managers       More than 200           Yes
# 3                 Professionals  Between 20 and 199            No
# 4                      Managers    Between 5 and 19           Yes
#
#                                     household           years_at_job  \
# 0           Couple with no dependent children      More than 5 years
# 1              Couple with dependent children      More than 5 years
# 2  One  parent family with dependent children      More than 5 years
# 3              Couple with dependent children  Between 1 and 5 years
# 4           Couple with no dependent children      More than 5 years
#
#   metro_or_regional rw_percentage_2020  ...  \
# 0          Regional    3-5 days remote  ...
# 1             Metro    0-3 days remote  ...
# 2             Metro    0-3 days remote  ...
# 3             Metro    3-5 days remote  ...
# 4             Metro    3-5 days remote  ...
#
#   if_no_covid_i_would_have_choice_about_rw productivity_remote_vs_office  \
# 0                        Strongly disagree          much more productive
# 1                           Somewhat agree               less productive
# 2                           Somewhat agree               less productive
# 3                           Somewhat agree             same productivity
# 4                        Strongly disagree               more productive
#
#   inperson_hours__commuting inperson_hours__working  \
# 0                       2.0                     8.0
# 1                       2.0                     7.0
# 2                       6.0                     1.0
# 3                       1.0                     9.0
# 4                       1.0                     8.0
#
#   inperson_hours__personal_family_time  \
# 0                                  2.0
# 1                                  3.0
# 2                                  6.0
# 3                                  1.0
# 4                                  3.5
#
#   inperson_hours_domestic_responsibilities remote_hours_commuting  \
# 0                                      2.0                    0.5
# 1                                      3.0                    0.0
# 2                                      5.0                    5.0
# 3                                      2.0                    0.0
# 4                                      2.0                    0.0
#
#   remote_hours_working remote_hours_personal_family_time  \
# 0                  8.0                               3.5
# 1                  7.0                               3.0
# 2                  2.0                               7.0
# 3                  9.0                               3.0
# 4                  6.0                               4.0
#
#   remote_hours_domestic_responsibilities
# 0                                    2.0
# 1                                    3.0
# 2                                    7.0
# 3                                    2.0
# 4                                    3.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns= 'preferred_rw_percentage_future')
X = pd.get_dummies(X)

# Create our target
y = df[target]

# %%
X.describe()
# Out:
#         birth_year  inperson_hours__commuting  inperson_hours__working  \
# count  3019.000000                3019.000000              3019.000000
# mean   1977.012587                   1.920543                 7.622295
# std      12.059818                   1.193116                 1.813712
# min    1900.000000                   0.000000                 1.000000
# 25%    1967.000000                   1.000000                 7.000000
# 50%    1978.000000                   2.000000                 8.000000
# 75%    1987.000000                   2.500000                 8.000000
# max    2002.000000                   6.000000                14.000000
#
#        inperson_hours__personal_family_time  \
# count                           3019.000000
# mean                               3.682458
# std                                2.053795
# min                                0.000000
# 25%                                2.000000
# 50%                                3.500000
# 75%                                5.000000
# max                               11.000000
#
#        inperson_hours_domestic_responsibilities  remote_hours_commuting  \
# count                               3019.000000             3019.000000
# mean                                   2.429530                0.731305
# std                                    1.586734                1.078736
# min                                   -1.000000                0.000000
# 25%                                    1.000000                0.000000
# 50%                                    2.000000                0.500000
# 75%                                    3.000000                1.000000
# max                                    8.000000                5.000000
#
#        remote_hours_working  remote_hours_personal_family_time  \
# count           3019.000000                        3019.000000
# mean               7.914660                           4.294395
# std                2.028679                           2.186404
# min                1.000000                           0.000000
# 25%                7.000000                           3.000000
# 50%                8.000000                           4.000000
# 75%                9.000000                           5.000000
# max               15.000000                          12.000000
#
#        remote_hours_domestic_responsibilities  gender_Female  ...  \
# count                             3019.000000    3019.000000  ...
# mean                                 2.719361       0.477973  ...
# std                                  1.640603       0.499597  ...
# min                                  0.000000       0.000000  ...
# 25%                                  2.000000       0.000000  ...
# 50%                                  2.500000       0.000000  ...
# 75%                                  4.000000       1.000000  ...
# max                                  8.000000       1.000000  ...
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely  \
# count                                        3019.000000
# mean                                            0.073534
# std                                             0.261055
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly agree  \
# count                                        3019.000000
# mean                                            0.121563
# std                                             0.326835
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly disagree  \
# count                                        3019.000000
# mean                                            0.038423
# std                                             0.192248
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very likely  \
# count                                        3019.000000
# mean                                            0.084134
# std                                             0.277634
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very unlikely  \
# count                                        3019.000000
# mean                                            0.065253
# std                                             0.247013
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        productivity_remote_vs_office_less productive  \
# count                                    3019.000000
# mean                                        0.109970
# std                                         0.312904
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        productivity_remote_vs_office_more productive  \
# count                                    3019.000000
# mean                                        0.214972
# std                                         0.410871
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        productivity_remote_vs_office_much less productive  \
# count                                        3019.000000
# mean                                            0.049023
# std                                             0.215952
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        productivity_remote_vs_office_much more productive  \
# count                                        3019.000000
# mean                                            0.371977
# std                                             0.483412
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        productivity_remote_vs_office_same productivity
# count                                      3019.000000
# mean                                          0.254058
# std                                           0.435402
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           1.000000
# max                                           1.000000
#
# [8 rows x 126 columns]

# %%
# Check the balance of our target values
y['preferred_rw_percentage_future'].value_counts()
# Out:
# 0-3 days remote    1840
# 3-5 days remote    1179
# Name: preferred_rw_percentage_future, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Ensemble Learners
#
# In this section, we compaerd two ensemble algorithms to determine which algorithm results in the best performance. We trained a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier .
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# Create a random forest classifier.
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=128, random_state=78) 

# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = rf_model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[379,  79],
#        [ 61, 236]])

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8110618558216811

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                        pre       rec       spe        f1       geo       iba       sup
#
# 0-3 days remote       0.86      0.83      0.79      0.84      0.81      0.66       458
# 3-5 days remote       0.75      0.79      0.83      0.77      0.81      0.66       297
#
#     avg / total       0.82      0.81      0.81      0.82      0.81      0.66       755

# %%
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_

sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.12324816745545442, 'preferred_rw_percentage_2020_0-3 days remote'),
#  (0.11139825200428372, 'preferred_rw_percentage_2020_3-5 days remote'),
#  (0.0537213115604658, 'rw_percentage_2020_3-5 days remote'),
#  (0.039310797273153335, 'rw_percentage_2020_0-3 days remote'),
#  (0.03403957301537556, 'birth_year'),
#  (0.024566140933206092, 'remote_hours_personal_family_time'),
#  (0.023104267500571866, 'inperson_hours__personal_family_time'),
#  (0.022759068220373685, 'remote_hours_working'),
#  (0.022541033155893193, 'inperson_hours__commuting'),
#  (0.02213295567225459, 'inperson_hours__working'),
#  (0.02132999949513569, 'inperson_hours_domestic_responsibilities'),
#  (0.021083250080721115, 'remote_hours_domestic_responsibilities'),
#  (0.01838489177171691, 'rw_collaboration_easy_Strongly agree'),
#  (0.01837214058981317, 'manage_others_0-3 days remote'),
#  (0.01726526309656081, 'remote_hours_commuting'),
#  (0.01099588920855011, 'manage_others_No'),
#  (0.010863447265962457, 'productivity_remote_vs_office_much more productive'),
#  (0.008631579605236325, 'org_prepared_for_rw_Strongly agree'),
#  (0.008500420731571959, 'productivity_remote_vs_office_less productive'),
#  (0.007559398417237946, 'manage_others_Yes'),
#  (0.00747511630067626, 'org_encouraged_rw_Strongly agree'),
#  (0.0070682778126244196, 'organization_size_More than 200'),
#  (0.0070061557430706875, 'household_Couple with dependent children'),
#  (0.006938359917482379, 'rw_permission_is_attainable_Strongly agree'),
#  (0.00659141633662179, 'years_at_job_More than 5 years'),
#  (0.006590388161820975, 'industry_desc_Other'),
#  (0.0065382469939894074, 'years_at_job_Between 1 and 5 years'),
#  (0.006518968560397917, 'occupation_desc_Professionals'),
#  (0.006450935277969613, 'rw_is_common_at_org_Strongly agree'),
#  (0.006362687669927546, 'rw_collaboration_easy_Somewhat agree'),
#  (0.0061742958920488235, 'rw_is_common_at_org_Somewhat agree'),
#  (0.0061606924774782, 'gender_Female'),
#  (0.006100648466036107, 'organization_size_Between 20 and 199'),
#  (0.0060537322423900525,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat agree'),
#  (0.005988114499321486, 'gender_Male'),
#  (0.005909854699924043, 'org_prepared_for_rw_Somewhat agree'),
#  (0.0058411587086961815, 'household_Couple with no dependent children'),
#  (0.005743166467705737, 'rw_permission_is_attainable_Somewhat agree'),
#  (0.005710262002981519, 'productivity_remote_vs_office_more productive'),
#  (0.0056350247994673835,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat likely'),
#  (0.00537980367036614, 'household_Single person'),
#  (0.005221200341794842, 'productivity_remote_vs_office_same productivity'),
#  (0.005188504759331423, 'if_no_covid_employer_support_rw_Somewhat agree'),
#  (0.005041115564375469,
#   'if_no_covid_employer_encourage_rw_Neither agree nor disagree'),
#  (0.005025950256580047, 'org_encouraged_rw_Somewhat agree'),
#  (0.005013000188598293, 'if_no_covid_employer_encourage_rw_Somewhat likely'),
#  (0.004979030749132976, 'metro_or_regional_Metro'),
#  (0.004969044542553751, 'occupation_desc_Other'),
#  (0.0049304493440803215, 'rw_collaboration_easy_Neither agree nor disagree'),
#  (0.0049303973759575355, 'if_no_covid_employer_encourage_rw_Somewhat agree'),
#  (0.0048176319336851485, 'rw_collaboration_easy_Somewhat disagree'),
#  (0.004459675069491701, 'occupation_desc_Managers'),
#  (0.004436816731658761, 'if_no_covid_employer_encourage_rw_Very likely'),
#  (0.004370042089393942, 'metro_or_regional_Regional'),
#  (0.004280486471957363,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly agree'),
#  (0.004241180558108922, 'years_at_job_Between 6 and 12 months'),
#  (0.004232192620409663, 'organization_size_Between 5 and 19'),
#  (0.004130471894042192, 'org_encouraged_rw_Neither agree nor disagree'),
#  (0.004126105978678991,
#   'if_no_covid_employer_support_rw_Neither agree nor disagree'),
#  (0.0040977119854313255, 'if_no_covid_employer_encourage_rw_Strongly agree'),
#  (0.004085744337939127, 'occupation_desc_Clerical and administrative '),
#  (0.004041734389498798, 'industry_desc_Education and Training'),
#  (0.004025235937871039, 'rw_is_common_at_org_Neither agree nor disagree'),
#  (0.003989442510661336,
#   'industry_desc_Professional, Scientific and Technical Services'),
#  (0.003936729263139806, 'if_no_covid_employer_support_rw_Somewhat disagree'),
#  (0.003732156845216971,
#   'industry_desc_Information Media and Telecommunications'),
#  (0.0037190465129555137, 'org_prepared_for_rw_Neither agree nor disagree'),
#  (0.003703619981734696, 'if_no_covid_employer_support_rw_Strongly agree'),
#  (0.0037013047519916815, 'if_no_covid_employer_support_rw_Somewhat likely'),
#  (0.0036229981307584497,
#   'rw_permission_is_attainable_Neither agree nor disagree'),
#  (0.0035956923628276843,
#   'if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree'),
#  (0.003571043353699607, 'household_One parent family with dependent children'),
#  (0.003570040881114865, 'if_no_covid_employer_encourage_rw_Somewhat unlikely'),
#  (0.003565143624211135, 'household_Group household'),
#  (0.0035494138673607374,
#   'if_no_covid_employer_encourage_rw_Somewhat disagree'),
#  (0.0034911314883883625, 'industry_desc_Financial and Insurance Services'),
#  (0.003474731188481117,
#   'if_no_covid_employer_support_rw_Neither unlikely or likely'),
#  (0.003443746280389079, 'industry_desc_Other Services'),
#  (0.0032474171221419205,
#   'if_no_covid_employer_encourage_rw_Neither unlikely or likely'),
#  (0.0031724238725950476, 'org_prepared_for_rw_Somewhat disagree'),
#  (0.003097128067381309, 'rw_is_common_at_org_Somewhat disagree'),
#  (0.0030858685263943347, 'industry_desc_Financial and Insurance'),
#  (0.0030844209501216598, 'if_no_covid_employer_support_rw_Very likely'),
#  (0.0030731986168943412, 'occupation_desc_Managers - Specialist Managers'),
#  (0.00306090451386953,
#   'occupation_desc_Managers - Chief Executives, General Managers and Legislators'),
#  (0.003059091349118686, 'organization_size_Between 1 and 4'),
#  (0.0029996915164588974, 'industry_desc_Health Care and Social Assistance'),
#  (0.0029811566601168978,
#   'if_no_covid_i_would_have_choice_about_rw_Very likely'),
#  (0.002901525747443062,
#   'if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely'),
#  (0.0028972855557234467, 'if_no_covid_employer_support_rw_Somewhat unlikely'),
#  (0.0027804580829009023,
#   'occupation_desc_Professionals - Business, Human Resource and Marketing Professionals'),
#  (0.002725868043636021,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat disagree'),
#  (0.0027020152313253472, 'rw_permission_is_attainable_Somewhat disagree'),
#  (0.002672428489748081, 'occupation_desc_Professionals - ICT Professionals'),
#  (0.002622618717540466, 'industry_desc_Retail Trade'),
#  (0.0026047857257057586,
#   'industry_desc_Professional, Scientific and Technical'),
#  (0.002598987258157737, 'rw_is_common_at_org_Strongly disagree'),
#  (0.0024430121386084854, 'household_Other one family household'),
#  (0.0023868914335444386, 'productivity_remote_vs_office_much less productive'),
#  (0.0023545600588788253, 'org_encouraged_rw_Somewhat disagree'),
#  (0.0022772459454130966,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely'),
#  (0.0021830199865504876, 'if_no_covid_employer_encourage_rw_Very unlikely'),
#  (0.002069181500126347,
#   'if_no_covid_i_would_have_choice_about_rw_Very unlikely'),
#  (0.0020149700934621456, 'if_no_covid_employer_support_rw_Very unlikely'),
#  (0.001976770573654906, 'if_no_covid_employer_encourage_rw_Strongly disagree'),
#  (0.0018184412628614354, 'household_Multiple family household'),
#  (0.0017702477502959024,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly disagree'),
#  (0.0017064230453429764, 'rw_permission_is_attainable_Strongly disagree'),
#  (0.001685083318025472,
#   'occupation_desc_Professionals - Education Professionals'),
#  (0.0015909883634405507,
#   'occupation_desc_Professionals - Design, Engineering, Science and Transport Professionals'),
#  (0.001480389957854482, 'org_encouraged_rw_Strongly disagree'),
#  (0.0014511711568933943, 'if_no_covid_employer_support_rw_Strongly disagree'),
#  (0.001422317465567173, 'org_prepared_for_rw_Strongly disagree'),
#  (0.0013130478316940124,
#   'household_One  parent family with dependent children'),
#  (0.0012423433867733286,
#   'organization_size_I am a sole trader/owner-operator'),
#  (0.00119451140620421, 'occupation_desc_Sales '),
#  (0.0011190349254400957, 'organization_size_I am the only employee'),
#  (0.0007110662145397546, 'rw_collaboration_easy_Strongly disagree'),
#  (0.00024931479448423507, 'org_encouraged_rw_0-3 days remote'),
#  (0.00021229018089304633, 'rw_collaboration_easy_0-3 days remote'),
#  (0.00021169892674505994, 'rw_is_common_at_org_0-3 days remote'),
#  (0.00020647863227653192, 'rw_permission_is_attainable_0-3 days remote'),
#  (0.0001236978081515335, 'org_prepared_for_rw_0-3 days remote'),
#  (4.177722043543785e-05, 'gender_Rather not say'),
#  (2.163265653112061e-05, 'gender_I would rather not say'),
#  (0.0, 'gender_Other')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state=42)
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(random_state=42)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8110618558216811

# %%
# Display the confusion matrix
y_pred = eec.predict(X_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[356 102]
#  [ 32 265]]

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                        pre       rec       spe        f1       geo       iba       sup
#
# 0-3 days remote       0.92      0.78      0.89      0.84      0.83      0.69       458
# 3-5 days remote       0.72      0.89      0.78      0.80      0.83      0.70       297
#
#     avg / total       0.84      0.82      0.85      0.82      0.83      0.69       755
