# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Preliminary Cleaning/Setup

# %%
columns = [
"birth_year",
"gender",
"industry_desc",
"occupation_desc",
"organization_size",
"manage_others",
"household",
"years_at_job",
"metro_or_regional",
"rw_percentage_2020",
"org_encouraged_rw",
"org_prepared_for_rw",
"rw_is_common_at_org",
"rw_permission_is_attainable",
"rw_collaboration_easy",
#"preferred_rw_percentage_2020",
#"preferred_rw_percentage_future",
"if_no_covid_employer_encourage_rw",
"if_no_covid_employer_support_rw",
"if_no_covid_i_would_have_choice_about_rw",
"productivity_remote_vs_office",
"inperson_hours__commuting",
"inperson_hours__working",
"inperson_hours__personal_family_time",
"inperson_hours_domestic_responsibilities",
"remote_hours_commuting",
"remote_hours_working",
"remote_hours_personal_family_time",
"remote_hours_domestic_responsibilities",
]

target = ["productivity_remote_vs_office"]

# %%
# Load the data
file_path = Path('merged_df_cleaned_040323.csv')
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()

# Convert the target column values to More_or_same_productive and less_productive based on their values
x = dict.fromkeys(['more productive','much more productive','same productivity'], 'more_or_same_productive')
df = df.replace(x)

x = dict.fromkeys(['less productive', 'much less productive'], 'less_productive')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    birth_year  gender                                    industry_desc  \
# 0        1972  Female                                            Other
# 1        1972    Male                                            Other
# 2        1982    Male                                            Other
# 3        1987  Female  Professional, Scientific and Technical Services
# 4        1991    Male                                            Other
#
#                 occupation_desc   organization_size manage_others  \
# 0  Clerical and administrative   Between 20 and 199            No
# 1                      Managers     Between 1 and 4           Yes
# 2                      Managers       More than 200           Yes
# 3                 Professionals  Between 20 and 199            No
# 4                      Managers    Between 5 and 19           Yes
#
#                                     household           years_at_job  \
# 0           Couple with no dependent children      More than 5 years
# 1              Couple with dependent children      More than 5 years
# 2  One  parent family with dependent children      More than 5 years
# 3              Couple with dependent children  Between 1 and 5 years
# 4           Couple with no dependent children      More than 5 years
#
#   metro_or_regional rw_percentage_2020  ...  \
# 0          Regional           4-5 days  ...
# 1             Metro           1-2 days  ...
# 2             Metro           2-3 days  ...
# 3             Metro           4-5 days  ...
# 4             Metro           4-5 days  ...
#
#   if_no_covid_i_would_have_choice_about_rw productivity_remote_vs_office  \
# 0                        Strongly disagree       more_or_same_productive
# 1                           Somewhat agree               less_productive
# 2                           Somewhat agree               less_productive
# 3                           Somewhat agree       more_or_same_productive
# 4                        Strongly disagree       more_or_same_productive
#
#   inperson_hours__commuting inperson_hours__working  \
# 0                       2.0                     8.0
# 1                       2.0                     7.0
# 2                       6.0                     1.0
# 3                       1.0                     9.0
# 4                       1.0                     8.0
#
#   inperson_hours__personal_family_time  \
# 0                                  2.0
# 1                                  3.0
# 2                                  6.0
# 3                                  1.0
# 4                                  3.5
#
#   inperson_hours_domestic_responsibilities remote_hours_commuting  \
# 0                                      2.0                    0.5
# 1                                      3.0                    0.0
# 2                                      5.0                    5.0
# 3                                      2.0                    0.0
# 4                                      2.0                    0.0
#
#   remote_hours_working remote_hours_personal_family_time  \
# 0                  8.0                               3.5
# 1                  7.0                               3.0
# 2                  2.0                               7.0
# 3                  9.0                               3.0
# 4                  6.0                               4.0
#
#    remote_hours_domestic_responsibilities
# 0                                     2.0
# 1                                     3.0
# 2                                     7.0
# 3                                     2.0
# 4                                     3.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns= 'productivity_remote_vs_office')
X = pd.get_dummies(X)

# Create our target
y = df[target]

# %%
X.describe()
# Out:
#         birth_year  inperson_hours__commuting  inperson_hours__working  \
# count  3019.000000                3019.000000              3019.000000
# mean   1977.012587                   1.920543                 7.622295
# std      12.059818                   1.193116                 1.813712
# min    1900.000000                   0.000000                 1.000000
# 25%    1967.000000                   1.000000                 7.000000
# 50%    1978.000000                   2.000000                 8.000000
# 75%    1987.000000                   2.500000                 8.000000
# max    2002.000000                   6.000000                14.000000
#
#        inperson_hours__personal_family_time  \
# count                           3019.000000
# mean                               3.682458
# std                                2.053795
# min                                0.000000
# 25%                                2.000000
# 50%                                3.500000
# 75%                                5.000000
# max                               11.000000
#
#        inperson_hours_domestic_responsibilities  remote_hours_commuting  \
# count                               3019.000000             3019.000000
# mean                                   2.429530                0.731305
# std                                    1.586734                1.078736
# min                                   -1.000000                0.000000
# 25%                                    1.000000                0.000000
# 50%                                    2.000000                0.500000
# 75%                                    3.000000                1.000000
# max                                    8.000000                5.000000
#
#        remote_hours_working  remote_hours_personal_family_time  \
# count           3019.000000                        3019.000000
# mean               7.914660                           4.294395
# std                2.028679                           2.186404
# min                1.000000                           0.000000
# 25%                7.000000                           3.000000
# 50%                8.000000                           4.000000
# 75%                9.000000                           5.000000
# max               15.000000                          12.000000
#
#        remote_hours_domestic_responsibilities  gender_Female  ...  \
# count                             3019.000000    3019.000000  ...
# mean                                 2.719361       0.477973  ...
# std                                  1.640603       0.499597  ...
# min                                  0.000000       0.000000  ...
# 25%                                  2.000000       0.000000  ...
# 50%                                  2.500000       0.000000  ...
# 75%                                  4.000000       1.000000  ...
# max                                  8.000000       1.000000  ...
#
#        if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree  \
# count                                        3019.000000
# mean                                            0.103345
# std                                             0.304460
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely  \
# count                                        3019.000000
# mean                                            0.127194
# std                                             0.333246
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat agree  \
# count                                        3019.000000
# mean                                            0.181186
# std                                             0.385236
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat disagree  \
# count                                        3019.000000
# mean                                            0.054654
# std                                             0.227341
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat likely  \
# count                                        3019.000000
# mean                                            0.150712
# std                                             0.357827
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely  \
# count                                        3019.000000
# mean                                            0.073534
# std                                             0.261055
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly agree  \
# count                                        3019.000000
# mean                                            0.121563
# std                                             0.326835
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly disagree  \
# count                                        3019.000000
# mean                                            0.038423
# std                                             0.192248
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very likely  \
# count                                        3019.000000
# mean                                            0.084134
# std                                             0.277634
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very unlikely
# count                                        3019.000000
# mean                                            0.065253
# std                                             0.247013
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
# [8 rows x 122 columns]

# %%
# Check the balance of our target values
y['productivity_remote_vs_office'].value_counts()
# Out:
# more_or_same_productive    2539
# less_productive             480
# Name: productivity_remote_vs_office, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Ensemble Learners
#
# In this section, we compaerd two ensemble algorithms to determine which algorithm results in the best performance. We trained a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier .
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# Create a random forest classifier.
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=128, random_state=78) 

# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = rf_model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[  3, 109],
#        [  1, 642]])

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5126152521661853

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.75      0.03      1.00      0.05      0.16      0.02       112
# more_or_same_productive       0.85      1.00      0.03      0.92      0.16      0.03       643
#
#             avg / total       0.84      0.85      0.17      0.79      0.16      0.03       755

# %%
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_

sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.05615944263621798, 'birth_year'),
#  (0.039797776048315546, 'remote_hours_personal_family_time'),
#  (0.038858925680651656, 'remote_hours_working'),
#  (0.03562082811865736, 'inperson_hours__personal_family_time'),
#  (0.03338164851776192, 'remote_hours_domestic_responsibilities'),
#  (0.03324095767568354, 'inperson_hours__commuting'),
#  (0.03249641467150697, 'inperson_hours_domestic_responsibilities'),
#  (0.0319533571535561, 'inperson_hours__working'),
#  (0.025765811404703843, 'remote_hours_commuting'),
#  (0.02342103868192156, 'rw_collaboration_easy_Somewhat disagree'),
#  (0.018036370237240206, 'rw_collaboration_easy_Strongly agree'),
#  (0.013185208638046673, 'rw_percentage_2020_0-1 days'),
#  (0.011683418841857855, 'organization_size_More than 200'),
#  (0.01123279569695511, 'household_Couple with dependent children'),
#  (0.010921551948636114, 'org_prepared_for_rw_Somewhat disagree'),
#  (0.010857275411082366, 'years_at_job_More than 5 years'),
#  (0.010246821534786656, 'industry_desc_Other'),
#  (0.009887843156552377, 'rw_percentage_2020_4-5 days'),
#  (0.009868347261967721, 'manage_others_No'),
#  (0.00979109245363844, 'rw_collaboration_easy_Somewhat agree'),
#  (0.009710824486647184, 'household_Couple with no dependent children'),
#  (0.009541153845293351, 'years_at_job_Between 1 and 5 years'),
#  (0.009458802567011237, 'gender_Female'),
#  (0.009343412118447726, 'manage_others_Yes'),
#  (0.009310444023430177, 'gender_Male'),
#  (0.00921323781623612, 'org_encouraged_rw_Strongly agree'),
#  (0.009083820638454424, 'occupation_desc_Managers'),
#  (0.009013094194846123, 'rw_is_common_at_org_Strongly agree'),
#  (0.008973350568531808, 'industry_desc_Financial and Insurance Services'),
#  (0.008857213705747932, 'org_prepared_for_rw_Strongly agree'),
#  (0.008801001571290924, 'rw_is_common_at_org_Somewhat agree'),
#  (0.00876342170495709, 'org_encouraged_rw_Somewhat agree'),
#  (0.00866054287291496, 'organization_size_Between 20 and 199'),
#  (0.008602353956554763, 'rw_collaboration_easy_Neither agree nor disagree'),
#  (0.008510440043983795, 'org_prepared_for_rw_Somewhat agree'),
#  (0.00786455687725993, 'rw_permission_is_attainable_Strongly agree'),
#  (0.007725853207938124, 'rw_permission_is_attainable_Somewhat agree'),
#  (0.007627229190346479, 'household_Single person'),
#  (0.007593949484721543,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat agree'),
#  (0.007592811406079383, 'occupation_desc_Other'),
#  (0.007359841830564006, 'organization_size_Between 5 and 19'),
#  (0.007268551845504097, 'if_no_covid_employer_encourage_rw_Somewhat disagree'),
#  (0.0072625174682572026, 'metro_or_regional_Metro'),
#  (0.007216315805224848, 'if_no_covid_employer_encourage_rw_Somewhat agree'),
#  (0.007071963807952911, 'years_at_job_Between 6 and 12 months'),
#  (0.00703900614810266,
#   'if_no_covid_employer_encourage_rw_Neither unlikely or likely'),
#  (0.007034888802812828, 'occupation_desc_Professionals'),
#  (0.006982941868287159, 'metro_or_regional_Regional'),
#  (0.0068993823690507074, 'rw_percentage_2020_2-3 days'),
#  (0.006887796279368359, 'industry_desc_Health Care and Social Assistance'),
#  (0.0067208593937433106,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat likely'),
#  (0.00659449983797202, 'org_prepared_for_rw_Neither agree nor disagree'),
#  (0.00645880380276966, 'household_Group household'),
#  (0.006454202353746854,
#   'industry_desc_Information Media and Telecommunications'),
#  (0.006318467204352714,
#   'rw_permission_is_attainable_Neither agree nor disagree'),
#  (0.006259866145755014, 'if_no_covid_employer_support_rw_Somewhat agree'),
#  (0.006252295932870327, 'rw_percentage_2020_1-2 days'),
#  (0.006194554246555744, 'org_encouraged_rw_Neither agree nor disagree'),
#  (0.006186323592872833, 'if_no_covid_employer_support_rw_Somewhat disagree'),
#  (0.006020961222946934,
#   'if_no_covid_employer_support_rw_Neither agree nor disagree'),
#  (0.00590688750327594,
#   'if_no_covid_employer_encourage_rw_Neither agree nor disagree'),
#  (0.00566379614603292, 'rw_is_common_at_org_Somewhat disagree'),
#  (0.005562274946409208,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely'),
#  (0.00547788721476495,
#   'if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely'),
#  (0.005472938560545119, 'if_no_covid_employer_support_rw_Somewhat likely'),
#  (0.005397999888460392,
#   'if_no_covid_employer_support_rw_Neither unlikely or likely'),
#  (0.005357938688756739, 'industry_desc_Other Services'),
#  (0.00525090376146171, 'rw_collaboration_easy_Strongly disagree'),
#  (0.005244625210265421, 'if_no_covid_employer_encourage_rw_Somewhat likely'),
#  (0.005243562324431548, 'if_no_covid_employer_encourage_rw_Somewhat unlikely'),
#  (0.005209478725478615, 'rw_is_common_at_org_Neither agree nor disagree'),
#  (0.005104515542520849,
#   'if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree'),
#  (0.005068385135800918, 'industry_desc_Education and Training'),
#  (0.005067075411461958,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat disagree'),
#  (0.004852572312274109, 'rw_permission_is_attainable_Somewhat disagree'),
#  (0.004696977739693408, 'rw_is_common_at_org_Strongly disagree'),
#  (0.004673151539109674, 'rw_percentage_2020_3-4 days'),
#  (0.004643799961952578, 'occupation_desc_Clerical and administrative '),
#  (0.004624631271501077, 'industry_desc_Financial and Insurance'),
#  (0.004594354774807973,
#   'if_no_covid_i_would_have_choice_about_rw_Very unlikely'),
#  (0.004479517722416333, 'if_no_covid_employer_support_rw_Somewhat unlikely'),
#  (0.00441091861702455,
#   'industry_desc_Professional, Scientific and Technical Services'),
#  (0.00440418996859035, 'organization_size_Between 1 and 4'),
#  (0.00439686247853215, 'industry_desc_Retail Trade'),
#  (0.004272309306581237,
#   'occupation_desc_Managers - Chief Executives, General Managers and Legislators'),
#  (0.004242237987058969,
#   'occupation_desc_Professionals - Business, Human Resource and Marketing Professionals'),
#  (0.004218966842328457, 'if_no_covid_employer_encourage_rw_Strongly agree'),
#  (0.004212588553870694,
#   'if_no_covid_i_would_have_choice_about_rw_Very likely'),
#  (0.004151190250405186,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly agree'),
#  (0.004080434086757279, 'if_no_covid_employer_support_rw_Strongly agree'),
#  (0.00402753563327837, 'if_no_covid_employer_encourage_rw_Very unlikely'),
#  (0.0039049915140716854, 'occupation_desc_Managers - Specialist Managers'),
#  (0.0038774696585131413, 'org_encouraged_rw_Somewhat disagree'),
#  (0.0038485181311477537,
#   'industry_desc_Professional, Scientific and Technical'),
#  (0.003685239622003354,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly disagree'),
#  (0.003616972360346498, 'if_no_covid_employer_support_rw_Very likely'),
#  (0.00344969055034026, 'org_prepared_for_rw_Strongly disagree'),
#  (0.0034387318481861264, 'manage_others_No response'),
#  (0.0033988134732436726,
#   'household_One parent family with dependent children'),
#  (0.0033127768318406987, 'household_Multiple family household'),
#  (0.0030916630559551773, 'occupation_desc_Sales '),
#  (0.0030626006928530765, 'if_no_covid_employer_support_rw_Very unlikely'),
#  (0.0030261993798224216,
#   'occupation_desc_Professionals - Design, Engineering, Science and Transport Professionals'),
#  (0.0030003702963399283,
#   'if_no_covid_employer_encourage_rw_Strongly disagree'),
#  (0.0028291480292291222, 'if_no_covid_employer_encourage_rw_Very likely'),
#  (0.0028177554641062247, 'if_no_covid_employer_support_rw_Strongly disagree'),
#  (0.0027603142069474464, 'org_encouraged_rw_Strongly disagree'),
#  (0.0026163016236524154,
#   'occupation_desc_Professionals - Education Professionals'),
#  (0.0025646198009653264, 'occupation_desc_Professionals - ICT Professionals'),
#  (0.002514391260281373, 'rw_permission_is_attainable_Strongly disagree'),
#  (0.002504000708621694, 'household_Other one family household'),
#  (0.0023857823531455275,
#   'household_One  parent family with dependent children'),
#  (0.0018312971563857155, 'organization_size_I am the only employee'),
#  (0.0016382404503444516, 'rw_permission_is_attainable_No response'),
#  (0.0012616089029037375,
#   'organization_size_I am a sole trader/owner-operator'),
#  (0.0010864723951336363, 'rw_collaboration_easy_No response'),
#  (0.001011496249045109, 'rw_is_common_at_org_No response'),
#  (0.0009211477296659938, 'org_encouraged_rw_No response'),
#  (0.0007910783416326103, 'org_prepared_for_rw_No response'),
#  (0.0006033197982839973, 'gender_Other'),
#  (0.0, 'gender_Rather not say'),
#  (0.0, 'gender_I would rather not say')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state=42)
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(random_state=42)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5126152521661853

# %%
# Display the confusion matrix
y_pred = eec.predict(X_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 65  47]
#  [228 415]]

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.22      0.58      0.65      0.32      0.61      0.37       112
# more_or_same_productive       0.90      0.65      0.58      0.75      0.61      0.38       643
#
#             avg / total       0.80      0.64      0.59      0.69      0.61      0.38       755
