# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Preliminary Cleaning/Setup

# %%
columns = [
"birth_year",
"gender",
"industry_desc",
"occupation_desc",
"organization_size",
"manage_others",
"household",
"years_at_job",
"metro_or_regional",
"rw_percentage_2020",
"org_encouraged_rw",
"org_prepared_for_rw",
"rw_is_common_at_org",
"rw_permission_is_attainable",
"rw_collaboration_easy",
"preferred_rw_percentage_2020",
"preferred_rw_percentage_future",
"if_no_covid_employer_encourage_rw",
"if_no_covid_employer_support_rw",
"if_no_covid_i_would_have_choice_about_rw",
"productivity_remote_vs_office",
"inperson_hours__commuting",
"inperson_hours__working",
"inperson_hours__personal_family_time",
"inperson_hours_domestic_responsibilities",
"remote_hours_commuting",
"remote_hours_working",
"remote_hours_personal_family_time",
"remote_hours_domestic_responsibilities",
]

target = ["productivity_remote_vs_office"]

# %%
# Load the data
file_path = Path('merged_df_cleaned_040323.csv')
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()

# Convert the target column values to More_or_same_productive and less_productive based on their values
x = dict.fromkeys(['more productive','much more productive','same productivity'], 'more_or_same_productive')
df = df.replace(x)

x = dict.fromkeys(['less productive', 'much less productive'], 'less_productive')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    birth_year  gender                                    industry_desc  \
# 0        1972  Female                                            Other
# 1        1972    Male                                            Other
# 2        1982    Male                                            Other
# 3        1987  Female  Professional, Scientific and Technical Services
# 4        1991    Male                                            Other
#
#                 occupation_desc   organization_size manage_others  \
# 0  Clerical and administrative   Between 20 and 199            No
# 1                      Managers     Between 1 and 4           Yes
# 2                      Managers       More than 200           Yes
# 3                 Professionals  Between 20 and 199            No
# 4                      Managers    Between 5 and 19           Yes
#
#                                     household           years_at_job  \
# 0           Couple with no dependent children      More than 5 years
# 1              Couple with dependent children      More than 5 years
# 2  One  parent family with dependent children      More than 5 years
# 3              Couple with dependent children  Between 1 and 5 years
# 4           Couple with no dependent children      More than 5 years
#
#   metro_or_regional rw_percentage_2020  ...  \
# 0          Regional           4-5 days  ...
# 1             Metro           1-2 days  ...
# 2             Metro           2-3 days  ...
# 3             Metro           4-5 days  ...
# 4             Metro           4-5 days  ...
#
#   if_no_covid_i_would_have_choice_about_rw productivity_remote_vs_office  \
# 0                        Strongly disagree       more_or_same_productive
# 1                           Somewhat agree               less_productive
# 2                           Somewhat agree               less_productive
# 3                           Somewhat agree       more_or_same_productive
# 4                        Strongly disagree       more_or_same_productive
#
#   inperson_hours__commuting inperson_hours__working  \
# 0                       2.0                     8.0
# 1                       2.0                     7.0
# 2                       6.0                     1.0
# 3                       1.0                     9.0
# 4                       1.0                     8.0
#
#   inperson_hours__personal_family_time  \
# 0                                  2.0
# 1                                  3.0
# 2                                  6.0
# 3                                  1.0
# 4                                  3.5
#
#   inperson_hours_domestic_responsibilities remote_hours_commuting  \
# 0                                      2.0                    0.5
# 1                                      3.0                    0.0
# 2                                      5.0                    5.0
# 3                                      2.0                    0.0
# 4                                      2.0                    0.0
#
#   remote_hours_working remote_hours_personal_family_time  \
# 0                  8.0                               3.5
# 1                  7.0                               3.0
# 2                  2.0                               7.0
# 3                  9.0                               3.0
# 4                  6.0                               4.0
#
#   remote_hours_domestic_responsibilities
# 0                                    2.0
# 1                                    3.0
# 2                                    7.0
# 3                                    2.0
# 4                                    3.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = df.drop(columns= 'productivity_remote_vs_office')
X = pd.get_dummies(X)

# Create our target
y = df[target]

# %%
X.describe()
# Out:
#         birth_year  inperson_hours__commuting  inperson_hours__working  \
# count  3019.000000                3019.000000              3019.000000
# mean   1977.012587                   1.920543                 7.622295
# std      12.059818                   1.193116                 1.813712
# min    1900.000000                   0.000000                 1.000000
# 25%    1967.000000                   1.000000                 7.000000
# 50%    1978.000000                   2.000000                 8.000000
# 75%    1987.000000                   2.500000                 8.000000
# max    2002.000000                   6.000000                14.000000
#
#        inperson_hours__personal_family_time  \
# count                           3019.000000
# mean                               3.682458
# std                                2.053795
# min                                0.000000
# 25%                                2.000000
# 50%                                3.500000
# 75%                                5.000000
# max                               11.000000
#
#        inperson_hours_domestic_responsibilities  remote_hours_commuting  \
# count                               3019.000000             3019.000000
# mean                                   2.429530                0.731305
# std                                    1.586734                1.078736
# min                                   -1.000000                0.000000
# 25%                                    1.000000                0.000000
# 50%                                    2.000000                0.500000
# 75%                                    3.000000                1.000000
# max                                    8.000000                5.000000
#
#        remote_hours_working  remote_hours_personal_family_time  \
# count           3019.000000                        3019.000000
# mean               7.914660                           4.294395
# std                2.028679                           2.186404
# min                1.000000                           0.000000
# 25%                7.000000                           3.000000
# 50%                8.000000                           4.000000
# 75%                9.000000                           5.000000
# max               15.000000                          12.000000
#
#        remote_hours_domestic_responsibilities  gender_Female  ...  \
# count                             3019.000000    3019.000000  ...
# mean                                 2.719361       0.477973  ...
# std                                  1.640603       0.499597  ...
# min                                  0.000000       0.000000  ...
# 25%                                  2.000000       0.000000  ...
# 50%                                  2.500000       0.000000  ...
# 75%                                  4.000000       1.000000  ...
# max                                  8.000000       1.000000  ...
#
#        if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree  \
# count                                        3019.000000
# mean                                            0.103345
# std                                             0.304460
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely  \
# count                                        3019.000000
# mean                                            0.127194
# std                                             0.333246
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat agree  \
# count                                        3019.000000
# mean                                            0.181186
# std                                             0.385236
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat disagree  \
# count                                        3019.000000
# mean                                            0.054654
# std                                             0.227341
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat likely  \
# count                                        3019.000000
# mean                                            0.150712
# std                                             0.357827
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely  \
# count                                        3019.000000
# mean                                            0.073534
# std                                             0.261055
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly agree  \
# count                                        3019.000000
# mean                                            0.121563
# std                                             0.326835
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Strongly disagree  \
# count                                        3019.000000
# mean                                            0.038423
# std                                             0.192248
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very likely  \
# count                                        3019.000000
# mean                                            0.084134
# std                                             0.277634
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        if_no_covid_i_would_have_choice_about_rw_Very unlikely
# count                                        3019.000000
# mean                                            0.065253
# std                                             0.247013
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
# [8 rows x 133 columns]

# %%
# Check the balance of our target values
y['productivity_remote_vs_office'].value_counts()
# Out:
# more_or_same_productive    2539
# less_productive             480
# Name: productivity_remote_vs_office, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Ensemble Learners
#
# In this section, we compaerd two ensemble algorithms to determine which algorithm results in the best performance. We trained a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier .
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# Create a random forest classifier.
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=128, random_state=78) 

# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = rf_model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[  7, 105],
#        [  1, 642]])

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5304723950233281

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.88      0.06      1.00      0.12      0.25      0.06       112
# more_or_same_productive       0.86      1.00      0.06      0.92      0.25      0.07       643
#
#             avg / total       0.86      0.86      0.20      0.80      0.25      0.07       755

# %%
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_

sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.04710795133268984, 'birth_year'),
#  (0.03522582211749134, 'remote_hours_personal_family_time'),
#  (0.032169944142902064, 'remote_hours_working'),
#  (0.03216724523188402, 'inperson_hours__personal_family_time'),
#  (0.03167107990838756, 'inperson_hours_domestic_responsibilities'),
#  (0.031456874926753385, 'remote_hours_domestic_responsibilities'),
#  (0.029127808763287757, 'inperson_hours__working'),
#  (0.028474811694017967, 'preferred_rw_percentage_future_0-1 days'),
#  (0.027601789808104345, 'preferred_rw_percentage_2020_0-1 days'),
#  (0.026814444478441495, 'inperson_hours__commuting'),
#  (0.02401127499430594, 'remote_hours_commuting'),
#  (0.019378786282843834, 'rw_collaboration_easy_Somewhat disagree'),
#  (0.013711902546821933, 'rw_collaboration_easy_Strongly agree'),
#  (0.012731572985368513, 'preferred_rw_percentage_future_4-5 days'),
#  (0.010577504012254964, 'org_prepared_for_rw_Somewhat disagree'),
#  (0.010287413603266729, 'preferred_rw_percentage_2020_4-5 days'),
#  (0.010139835415232116, 'industry_desc_Other'),
#  (0.009706558593651307, 'organization_size_More than 200'),
#  (0.009405649866621561, 'years_at_job_Between 1 and 5 years'),
#  (0.009320873308967675, 'rw_percentage_2020_0-1 days'),
#  (0.009238167139116597, 'gender_Male'),
#  (0.008706390369386266, 'household_Couple with dependent children'),
#  (0.008686462943859436, 'household_Couple with no dependent children'),
#  (0.008676068443233185, 'preferred_rw_percentage_future_1-2 days'),
#  (0.00866653714685798, 'years_at_job_More than 5 years'),
#  (0.008439245916174946, 'rw_collaboration_easy_Somewhat agree'),
#  (0.008434944599955693, 'preferred_rw_percentage_future_2-3 days'),
#  (0.008363954379135782, 'org_prepared_for_rw_Somewhat agree'),
#  (0.008302342315981709, 'manage_others_Yes'),
#  (0.008288786882495515, 'household_Single person'),
#  (0.00821085665270339, 'occupation_desc_Managers'),
#  (0.008201914943867376, 'manage_others_No'),
#  (0.008149130838885717, 'org_prepared_for_rw_Strongly agree'),
#  (0.008143294715769923, 'organization_size_Between 20 and 199'),
#  (0.007971385871673503, 'rw_percentage_2020_4-5 days'),
#  (0.007955886600481785, 'rw_is_common_at_org_Somewhat agree'),
#  (0.007937603841398496, 'gender_Female'),
#  (0.007912833773261647, 'rw_is_common_at_org_Strongly agree'),
#  (0.007792915905943948, 'rw_permission_is_attainable_Somewhat agree'),
#  (0.007457782997653265, 'org_encouraged_rw_Strongly agree'),
#  (0.007404097650366889, 'industry_desc_Financial and Insurance Services'),
#  (0.0073982605547140345, 'org_encouraged_rw_Somewhat agree'),
#  (0.0072731452648909945, 'rw_permission_is_attainable_Strongly agree'),
#  (0.0071076857749933125, 'preferred_rw_percentage_2020_2-3 days'),
#  (0.007088810144398825, 'org_encouraged_rw_Neither agree nor disagree'),
#  (0.007046619429313331, 'rw_collaboration_easy_Neither agree nor disagree'),
#  (0.006913245037367344, 'organization_size_Between 5 and 19'),
#  (0.006676878049401007, 'rw_percentage_2020_2-3 days'),
#  (0.006610041053543436, 'occupation_desc_Other'),
#  (0.006462808261997653,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat agree'),
#  (0.006363328435742287, 'years_at_job_Between 6 and 12 months'),
#  (0.006330201428883123, 'org_prepared_for_rw_Neither agree nor disagree'),
#  (0.006031825420050242, 'if_no_covid_employer_encourage_rw_Somewhat agree'),
#  (0.006003001796045739, 'metro_or_regional_Regional'),
#  (0.005840957928753299,
#   'rw_permission_is_attainable_Neither agree nor disagree'),
#  (0.00578962228108081, 'if_no_covid_employer_support_rw_Somewhat agree'),
#  (0.005762527941472263, 'occupation_desc_Professionals'),
#  (0.0057169066853041935, 'preferred_rw_percentage_2020_1-2 days'),
#  (0.005582281512717416, 'rw_percentage_2020_1-2 days'),
#  (0.00555040047273885, 'if_no_covid_employer_encourage_rw_Somewhat disagree'),
#  (0.005523596799896103, 'metro_or_regional_Metro'),
#  (0.005490712915180874, 'household_Group household'),
#  (0.00547307706841155,
#   'if_no_covid_employer_support_rw_Neither agree nor disagree'),
#  (0.005382872211820056,
#   'if_no_covid_employer_support_rw_Neither unlikely or likely'),
#  (0.005349174770886436, 'preferred_rw_percentage_future_3-4 days'),
#  (0.005342249308857404,
#   'if_no_covid_employer_encourage_rw_Neither unlikely or likely'),
#  (0.0052591563667994745,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat likely'),
#  (0.0052364781864080775, 'industry_desc_Health Care and Social Assistance'),
#  (0.005025102749689062,
#   'industry_desc_Information Media and Telecommunications'),
#  (0.005003493661060842, 'industry_desc_Other Services'),
#  (0.004925752031877672, 'rw_is_common_at_org_Somewhat disagree'),
#  (0.004789758227822643,
#   'industry_desc_Professional, Scientific and Technical Services'),
#  (0.004782107817518624, 'rw_is_common_at_org_Neither agree nor disagree'),
#  (0.004768464743120457, 'if_no_covid_employer_support_rw_Somewhat likely'),
#  (0.004748277124303178, 'if_no_covid_employer_encourage_rw_Somewhat likely'),
#  (0.0047259510794460035,
#   'if_no_covid_employer_encourage_rw_Somewhat unlikely'),
#  (0.004725149740674701,
#   'if_no_covid_i_would_have_choice_about_rw_Neither unlikely or likely'),
#  (0.004717519125838889, 'rw_is_common_at_org_Strongly disagree'),
#  (0.004699024088238769,
#   'if_no_covid_employer_encourage_rw_Neither agree nor disagree'),
#  (0.004681610597585208,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat unlikely'),
#  (0.004592251864087776, 'preferred_rw_percentage_2020_3-4 days'),
#  (0.0045603908193507, 'industry_desc_Retail Trade'),
#  (0.0044453669673677875, 'if_no_covid_employer_support_rw_Somewhat disagree'),
#  (0.004418944699921166, 'industry_desc_Financial and Insurance'),
#  (0.004394179311467474, 'rw_percentage_2020_3-4 days'),
#  (0.004393893786566139, 'organization_size_Between 1 and 4'),
#  (0.004352962111423495,
#   'if_no_covid_i_would_have_choice_about_rw_Neither agree nor disagree'),
#  (0.004351115733074836, 'if_no_covid_employer_encourage_rw_Strongly agree'),
#  (0.0042303548243649396,
#   'if_no_covid_i_would_have_choice_about_rw_Somewhat disagree'),
#  (0.004190846340160572, 'if_no_covid_employer_support_rw_Somewhat unlikely'),
#  (0.004108312395075041, 'rw_permission_is_attainable_Somewhat disagree'),
#  (0.003982519067407577, 'occupation_desc_Clerical and administrative '),
#  (0.003938722798487664, 'org_encouraged_rw_Somewhat disagree'),
#  (0.0038737462379653228,
#   'occupation_desc_Professionals - Business, Human Resource and Marketing Professionals'),
#  (0.003852010777437494,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly agree'),
#  (0.0037415102567282307,
#   'if_no_covid_i_would_have_choice_about_rw_Very unlikely'),
#  (0.0036899522393483903, 'industry_desc_Education and Training'),
#  (0.0036247857457147896, 'rw_collaboration_easy_Strongly disagree'),
#  (0.0036162073714584644, 'org_prepared_for_rw_Strongly disagree'),
#  (0.003590493037074251, 'if_no_covid_employer_encourage_rw_Very unlikely'),
#  (0.003540636162063883, 'org_encouraged_rw_Strongly disagree'),
#  (0.0034491592820505156,
#   'occupation_desc_Managers - Chief Executives, General Managers and Legislators'),
#  (0.0034140881019078862, 'if_no_covid_employer_support_rw_Very likely'),
#  (0.003382054549298864, 'if_no_covid_employer_support_rw_Strongly agree'),
#  (0.003327165132889921,
#   'if_no_covid_i_would_have_choice_about_rw_Very likely'),
#  (0.0031862728205603605, 'household_Multiple family household'),
#  (0.003130864920776317, 'occupation_desc_Managers - Specialist Managers'),
#  (0.002863546218100434, 'if_no_covid_employer_encourage_rw_Very likely'),
#  (0.0028592773169529447, 'rw_permission_is_attainable_Strongly disagree'),
#  (0.0028232969893492187,
#   'household_One parent family with dependent children'),
#  (0.0028076332961890836,
#   'industry_desc_Professional, Scientific and Technical'),
#  (0.0027178464791487115,
#   'if_no_covid_employer_encourage_rw_Strongly disagree'),
#  (0.002684516791993694, 'if_no_covid_employer_support_rw_Very unlikely'),
#  (0.0026199536282643025,
#   'if_no_covid_i_would_have_choice_about_rw_Strongly disagree'),
#  (0.0025947274220319877, 'preferred_rw_percentage_future_No response'),
#  (0.002436507928823322, 'occupation_desc_Sales '),
#  (0.0024091006308558666, 'manage_others_No response'),
#  (0.0023889862312336547, 'occupation_desc_Professionals - ICT Professionals'),
#  (0.0022233995815834906, 'if_no_covid_employer_support_rw_Strongly disagree'),
#  (0.0021366591132077886,
#   'household_One  parent family with dependent children'),
#  (0.0020733598797325376, 'household_Other one family household'),
#  (0.0020635344629678387,
#   'occupation_desc_Professionals - Design, Engineering, Science and Transport Professionals'),
#  (0.0019231384635031484,
#   'occupation_desc_Professionals - Education Professionals'),
#  (0.0015664468583383559,
#   'organization_size_I am a sole trader/owner-operator'),
#  (0.0014406520135998306, 'organization_size_I am the only employee'),
#  (0.0011708227889278586, 'rw_permission_is_attainable_No response'),
#  (0.0011221771906749277, 'rw_is_common_at_org_No response'),
#  (0.0009776207035221353, 'rw_collaboration_easy_No response'),
#  (0.0009451327945874579, 'org_encouraged_rw_No response'),
#  (0.0009079720014004527, 'org_prepared_for_rw_No response'),
#  (0.0006370598306394671, 'gender_Other'),
#  (0.0, 'gender_Rather not say'),
#  (0.0, 'gender_I would rather not say')]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state=42)
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(random_state=42)

# %%
# Calculated the balanced accuracy score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5304723950233281

# %%
# Display the confusion matrix
y_pred = eec.predict(X_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 69  43]
#  [214 429]]

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                pre       rec       spe        f1       geo       iba       sup
#
#         less_productive       0.24      0.62      0.67      0.35      0.64      0.41       112
# more_or_same_productive       0.91      0.67      0.62      0.77      0.64      0.41       643
#
#             avg / total       0.81      0.66      0.62      0.71      0.64      0.41       755
